# %%
import time
import requests

api_key = "0ed3d86910ae491aa8248aa7358cf38c"
server_url = "http://192.168.0.147:8096"
user_id = "e3cc30114c354b68995e36c06793dedc"

types_param = ",".join(["Movie", "Series", "Episode"])

# %%
start = time.time()

headers: dict = {
    "X-Emby-Authorization": (
        f'MediaBrowser Client="JellyfinMonitor", '
        f'Device="PythonScript", DeviceId="monitor-001", Version="1.0", Token="{api_key}"'
    ),
    "Accept": "application/json",
}

if user_id:
    url = f"{server_url}/Users/{user_id}/Items"
else:
    url = f"{server_url}/Items"

params = {
    "IncludeItemTypes": types_param,
    "Recursive": "true",
    "Fields": "UserData,Id,Name,Type,ProductionYear,SeriesName,ParentIndexNumber,IndexNumber,MediaSources,Path",
    "Filters": "IsPlayed",
}

try:
    resp = requests.get(url, headers=headers, params=params, timeout=300)
    resp.raise_for_status()
    data = resp.json()
except requests.RequestException as exc:
    self.logger.error("Failed to fetch items: %s", exc)

end = time.time()

print(f"Total runtime of the program is {end - start} seconds")
display(data)
# Out:
# Total runtime of the program is 0.22003650665283203 seconds
# {'Items': [{'Name': '... és a Pokol',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': 'dfbc3191ee6e969dfab2d8c4584849ef',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '1986-11-19T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': 'dfbc3191ee6e969dfab2d8c4584849ef',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'manon.des.sources.1080p-gyontato',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'CriticRating': 81,
#    'Path': '/movies/Manon des sources (1986) [imdbid-tt0091480]/manon.des.sources.1080p-gyontato.mkv',
#    'OfficialRating': 'PG',
#    'ChannelId': None,
#    'CommunityRating': 7.58,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 1986,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 1,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T15:00:43.0917128Z',
#     'Played': True,
#     'Key': '4481',
#     'ItemId': 'dfbc3191ee6e969dfab2d8c4584849ef'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Thumb': '58c16ff84dd354dda70c3e3a71cf7d0c',
#     'Logo': 'c40410e904771509f68863020364ff5f',
#     'Primary': '20bf74323a66949786ffa97dd8c6de4f'},
#    'BackdropImageTags': ['67c1a2326ab18a005827e1dad65d1eab'],
#    'ImageBlurHashes': {'Backdrop': {'67c1a2326ab18a005827e1dad65d1eab': 'WEC$_g%b0eOp-:-9f+-.IVIWoHxC%ytQxYRjR-WA%MtQe.RiXRoz'},
#     'Thumb': {'58c16ff84dd354dda70c3e3a71cf7d0c': 'WKE.pwyS9dMiovaM~ktOaMRlNbV]SzsVn%kUt5R+xsn*k9ocxWWV'},
#     'Logo': {'c40410e904771509f68863020364ff5f': 'HLHw-Hj@-lodE5R+xrxYWD~7azxYoKIrWWxYodWD'},
#     'Primary': {'20bf74323a66949786ffa97dd8c6de4f': 'dVD[wbV[I;xZxsR,R-kB0zbbt6W.xZs,smt6-UafM|a#'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '... hogy szaladnak a fák!',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '525f024d2ab59d90dd201690c7d5b91f',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '1966-04-15T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': '525f024d2ab59d90dd201690c7d5b91f',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'hogy szaladnak a fák!',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'HasSegments': False}],
#    'Path': '/movies/hogy szaladnak a fák! mkv [imdbid-tt0133009]/hogy szaladnak a fák!.mkv',
#    'ChannelId': None,
#    'CommunityRating': 7.2,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 1966,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 1,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T20:45:42.8843173Z',
#     'Played': True,
#     'Key': '336092',
#     'ItemId': '525f024d2ab59d90dd201690c7d5b91f'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': '880ab042552847b454f05f7f1b38736c'},
#    'BackdropImageTags': [],
#    'ImageBlurHashes': {'Primary': {'880ab042552847b454f05f7f1b38736c': 'dNFh^[OFSh^k0:^+-po}9aV?%1bc~CoykBR5tS%2xZ%M'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '...és hamarosan a sötétség',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '855bf92927df4eb9bc1a14d372d6caa1',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '1970-09-10T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': '855bf92927df4eb9bc1a14d372d6caa1',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'And.Soon.the.Darkness.1970.720p.BluRay.FLAC.x264.HuN-BAYLEE',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'HasSegments': False}],
#    'CriticRating': 38,
#    'Path': '/movies/And Soon the Darkness (1970) [imdbid-tt0065398]/And.Soon.the.Darkness.1970.720p.BluRay.FLAC.x264.HuN-BAYLEE.mkv',
#    'OfficialRating': 'HU-18',
#    'ChannelId': None,
#    'CommunityRating': 6.5,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 1970,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 1,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T21:07:45.2824871Z',
#     'Played': True,
#     'Key': '51992',
#     'ItemId': '855bf92927df4eb9bc1a14d372d6caa1'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': '4ce4625d6c3d6aff0e5473d8836e1c14',
#     'Logo': 'e2bbb1c36a801ddf935858678d400eff'},
#    'BackdropImageTags': ['c6dbf69aad29707abc4c46435676830c'],
#    'ImageBlurHashes': {'Backdrop': {'c6dbf69aad29707abc4c46435676830c': 'W+I~MXozR*tQt7xu?^ozj[ofofof-=oMoga~ogog-=jYaybIS1oz'},
#     'Primary': {'4ce4625d6c3d6aff0e5473d8836e1c14': 'dXL4jBnNt,?v9ZE0MwM{?wJ6$is.=|RmkXxtIURRE2R+'},
#     'Logo': {'e2bbb1c36a801ddf935858678d400eff': 'HEG[[{M{00t7D%M{RjWBt79Ft74nt79Fj[t7xu%M'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '...És Isten megteremté a nőt',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '6df5ecdccfb9f8a78b06e9d132f1ffb2',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '1956-11-28T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': '6df5ecdccfb9f8a78b06e9d132f1ffb2',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'És Isten megteremté a nőt 1956 1080p hun-gerdub',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'HasSegments': False}],
#    'CriticRating': 71,
#    'Path': '/movies/És Isten megteremté a nőt [imdbid-tt0049189]/És Isten megteremté a nőt 1956 1080p hun-gerdub.mkv',
#    'OfficialRating': 'PG',
#    'ChannelId': None,
#    'CommunityRating': 6.1,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 1956,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 3,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T21:13:41.4931367Z',
#     'Played': True,
#     'Key': '6df5ecdc-cfb9-f8a7-8b06-e9d132f1ffb2',
#     'ItemId': '6df5ecdccfb9f8a78b06e9d132f1ffb2'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Logo': '04d10bf37f0fb0931f126908841f0f45',
#     'Primary': '22644051e2f8463519032588a5d99eaf',
#     'Thumb': 'a698450e9c447be6c15ca9e382470822'},
#    'BackdropImageTags': ['7b7e092a4497ed5f88b633b14284a485'],
#    'ImageBlurHashes': {'Backdrop': {'7b7e092a4497ed5f88b633b14284a485': 'WfHK@N?It,R*Vs%L_4xu-qj[M{oz-;t7%2t7W=t7xuWWbbkCayof'},
#     'Logo': {'04d10bf37f0fb0931f126908841f0f45': 'OnEMLDfQayayayfQayoffQayfQfQfQfQ00fQj[j[j[fQfQ'},
#     'Primary': {'22644051e2f8463519032588a5d99eaf': 'drME4.rsENxG$%njnjt610bHxYbaWCkBbbRkI;X8a#V['},
#     'Thumb': {'a698450e9c447be6c15ca9e382470822': 'WiF~Ehs,oz%gxu%M~poJozxut7xa-;RkWBozbHWB-;WVWBozofjZ'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '#Karácsony',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '6467697a4c292b683bc587914b9148d0',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2022-11-25T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': '6467697a4c292b683bc587914b9148d0',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'Karacsony',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'Path': '/movies/Karacsony mkv [imdbid-tt9892854]/Karacsony.mkv',
#    'OfficialRating': 'G',
#    'ChannelId': None,
#    'CommunityRating': 5.317,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2022,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 3,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T21:17:14.0897157Z',
#     'Played': True,
#     'Key': '1028550',
#     'ItemId': '6467697a4c292b683bc587914b9148d0'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Logo': '3c7762e953f59336a4964df85af9d0d8',
#     'Thumb': '2dc456524d254d9c51afdccddc516478',
#     'Primary': 'dfe069f717244a4badb96a35fe3d0222'},
#    'BackdropImageTags': ['57ee64681b42ffac939e98eeab7cff52'],
#    'ImageBlurHashes': {'Backdrop': {'57ee64681b42ffac939e98eeab7cff52': 'W[L;4_r=t6SxoytR~VR-RjaKRjogtRbvn$o2WAoztkt7sAWrjZog'},
#     'Logo': {'3c7762e953f59336a4964df85af9d0d8': 'PXNsBI3P3SB*F?XRsBwg$%SeX7S2f6ofjZoLoMnin+W;fjbaSLj?'},
#     'Thumb': {'2dc456524d254d9c51afdccddc516478': 'W:N,SbadtRb]Mys:~WS5S$s:RQWqRlWYt8ogaLaexaj]tRbvWBae'},
#     'Primary': {'dfe069f717244a4badb96a35fe3d0222': 'd~LqC5%2oext~pkCWBn%tRR+afjbX9n$ofozxan$bIof'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '#kövessbe',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': 'f56a1f6cde09a364b729b33cef970198',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2020-07-03T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': 'f56a1f6cde09a364b729b33cef970198',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'Follow.Me.2160p.UHD.BluRay.DTS-HD.MA.5.1.HDR10+.x265.HuN-TRiNiTY',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'HasSegments': False}],
#    'CriticRating': 38,
#    'Path': '/movies/Follow Me 2160p UHD BluRay DTS-HD MA 5 1 HDR10+ x265 HuN-TRiNiTY [imdbid-tt8160834]/Follow.Me.2160p.UHD.BluRay.DTS-HD.MA.5.1.HDR10+.x265.HuN-TRiNiTY.mkv',
#    'OfficialRating': 'HU-18',
#    'ChannelId': None,
#    'CommunityRating': 6.222,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2020,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 1,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T21:14:29.7943755Z',
#     'Played': True,
#     'Key': '606625',
#     'ItemId': 'f56a1f6cde09a364b729b33cef970198'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': '55d27179ce86a1b7c46fd8948555785a',
#     'Thumb': '9a967b88ada5294f324aca793cd4618c',
#     'Logo': 'df3e9de0610aeb9efbaa0eecf23159eb'},
#    'BackdropImageTags': ['e0f82d22c4cd69e7078447826713d58c'],
#    'ImageBlurHashes': {'Backdrop': {'e0f82d22c4cd69e7078447826713d58c': 'W24Bg,NI0MkC.6$y~ANHE2xZx[r=^iWVE2a}%1s,$*odIpWC%1j['},
#     'Primary': {'55d27179ce86a1b7c46fd8948555785a': 'dd9b2,RjS$tRp{WYa$ozyDbcWBj[x^kCWWaeKjoeoLV@'},
#     'Thumb': {'9a967b88ada5294f324aca793cd4618c': 'WQ8~+gR-X8NbtQx].mbwRjWBoLt7x]kCRjWBV@ofyDkCWVa}n$oL'},
#     'Logo': {'df3e9de0610aeb9efbaa0eecf23159eb': 'HHJkl#xu%MRjt7%MRjt7of00ofRjM{RjRjofofWB'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '5 nap háború',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '09452393c8de6c55efde68e579c396ff',
#    'HasSubtitles': True,
#    'Container': 'mkv',
#    'PremiereDate': '2011-06-06T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': '09452393c8de6c55efde68e579c396ff',
#      'Path': '/downloaded/5.Days.of.War.2011.1080p.BR.Remux.AVC.DTS-HD.MA.5.1.HUN-CRW/5.Days.Of.War.2011.1080p.BR.Remux.AVC.DTS-HD.MA.5.1.HUN-CRW.mkv',
#      'Type': 'Default',
#      'Container': 'mkv',
#      'Size': 22298707662,
#      'Name': '5.Days.Of.War.2011.1080p.BR.Remux.AVC.DTS-HD.MA.5.1.HUN-CRW',
#      'IsRemote': False,
#      'ETag': 'bdb41a1f873c4dcee021c1920510b481',
#      'RunTimeTicks': 67827840000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'TimeBase': '1/1000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 26300360,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1080,
#        'Width': 1920,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '16:9',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 41,
#        'IsAnamorphic': False},
#       {'Codec': 'dts',
#        'Language': 'eng',
#        'TimeBase': '1/1000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'English - DTS-HD MA - 5.1 - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': '5.1',
#        'BitRate': 1895194,
#        'BitDepth': 16,
#        'Channels': 6,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'DTS-HD MA',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0},
#       {'Codec': 'ac3',
#        'Language': 'hun',
#        'TimeBase': '1/1000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'Hungarian - Dolby Digital - 5.1',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': '5.1',
#        'BitRate': 448000,
#        'Channels': 6,
#        'SampleRate': 48000,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Type': 'Audio',
#        'Index': 2,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0},
#       {'Codec': 'subrip',
#        'Language': 'hun',
#        'TimeBase': '1/1000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'Hungarian - Default - Forced - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': True,
#        'IsForced': True,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 3,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0},
#       {'Codec': 'subrip',
#        'Language': 'hun',
#        'TimeBase': '1/1000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'Hungarian - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 4,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0},
#       {'Codec': 'subrip',
#        'Language': 'eng',
#        'TimeBase': '1/1000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'English - Forced - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': False,
#        'IsForced': True,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 5,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0},
#       {'Codec': 'subrip',
#        'Language': 'eng',
#        'TimeBase': '1/1000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'English - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 6,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 28643554,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'CriticRating': 35,
#    'Path': '/movies/5 Days of War (2011) [imdbid-tt1486193]/5.Days.Of.War.2011.1080p.BR.Remux.AVC.DTS-HD.MA.5.1.HUN-CRW.mkv',
#    'OfficialRating': 'R',
#    'ChannelId': None,
#    'CommunityRating': 5.634,
#    'RunTimeTicks': 67827840000,
#    'ProductionYear': 2011,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 3,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T14:54:35.6704046Z',
#     'Played': True,
#     'Key': '09452393-c8de-6c55-efde-68e579c396ff',
#     'ItemId': '09452393c8de6c55efde68e579c396ff'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Logo': 'd7055883920144165bd51bd51838cee1',
#     'Primary': '1fa2f71938603c8f274e52ae071c6628',
#     'Thumb': '4e79ed24108f61ec3a592cc66e54b50c'},
#    'BackdropImageTags': ['4b0c19b0f288328487f21e8a6002f8a8'],
#    'ImageBlurHashes': {'Backdrop': {'4b0c19b0f288328487f21e8a6002f8a8': 'WdJar~?bDiIAM{%2~qtSIURjRkM{.8ShIoozkCIotSoKM|t7xuWA'},
#     'Logo': {'d7055883920144165bd51bd51838cee1': 'NFCo@7o11va|,so1o1jta|a|a|fQAqa|,sjtNufQ'},
#     'Primary': {'1fa2f71938603c8f274e52ae071c6628': 'dKK18h~o9Erq$-I;9axbnMWBtlx]rXt6-:RjDiWCxGxs'},
#     'Thumb': {'4e79ed24108f61ec3a592cc66e54b50c': 'WYKTo7$*0LoM9u%L#ijFMzM{tSjEtmozofkCr;oftQWCodR*aexu'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '9 dal',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': 'd7304a2504e8c9c5f0c47cfa4edeafb1',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2004-07-16T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': 'd7304a2504e8c9c5f0c47cfa4edeafb1',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'crls-9.songs.1080p',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'HasSegments': False}],
#    'CriticRating': 23,
#    'Path': '/movies/9 Songs (2004) [imdbid-tt0411705]/crls-9.songs.1080p.mkv',
#    'OfficialRating': 'NR',
#    'ChannelId': None,
#    'CommunityRating': 5.532,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2004,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 1,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-01T07:36:50.4947521Z',
#     'Played': True,
#     'Key': '27',
#     'ItemId': 'd7304a2504e8c9c5f0c47cfa4edeafb1'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': '2669a7234c19e0c5d592648d67e07702',
#     'Logo': '5d901c3d137c30a47e1583dd5b7987c5'},
#    'BackdropImageTags': ['6df970268474934bdd035bb0df08746b'],
#    'ImageBlurHashes': {'Backdrop': {'6df970268474934bdd035bb0df08746b': 'WXIq4AxF0#I9MxN{S64.tRt6%M-;xuD%-:%1oLsn-;WAxuM{Rjof'},
#     'Primary': {'2669a7234c19e0c5d592648d67e07702': 'dzLNS#s:oLxu~qbIozofb_oetRofRit7tRf6xaR+Rkay'},
#     'Logo': {'5d901c3d137c30a47e1583dd5b7987c5': 'HAN@4Hx]TK?Yx@xsW:${RQ};bbbIxra#baj[kAbG'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': '28 évvel később: A csonttemplom',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': 'bca4cb2ecd192b22ce54fb1ca7f3c164',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2026-01-14T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': 'bca4cb2ecd192b22ce54fb1ca7f3c164',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'fulcrum-28.years.later.the.bone.temple.2026.2160p.web.dvhdr.ma',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'Path': '/movies/28 Years Later The Bone Temple (2026) [imdbid-tt32141377]/fulcrum-28.years.later.the.bone.temple.2026.2160p.web.dvhdr.ma.mkv',
#    'OfficialRating': 'R',
#    'ChannelId': None,
#    'CommunityRating': 7.2,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2026,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 3,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-03-20T20:53:06.3903352Z',
#     'Played': True,
#     'Key': '1272837',
#     'ItemId': 'bca4cb2ecd192b22ce54fb1ca7f3c164'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Logo': 'b090f363ede1da2d83f68d29d2b49535',
#     'Thumb': 'b38c58f9c8ae272c14c8092053fcd7a3',
#     'Primary': '36bf14ea4f946278e34f1f346fb0e7da'},
#    'BackdropImageTags': ['af92962c5c53e2de4ac3078963bc813d'],
#    'ImageBlurHashes': {'Backdrop': {'af92962c5c53e2de4ac3078963bc813d': 'WPFgE.$ibuNeEg%1MzxZENR*xZWB9_R+bbxZ$$WX}?a}$%s:Rks:'},
#     'Logo': {'b090f363ede1da2d83f68d29d2b49535': 'PaF$Y7-;%Mt7M{D%D%IUIUt7ofofWBayt7of00xuofWBWBayWBj['},
#     'Thumb': {'b38c58f9c8ae272c14c8092053fcd7a3': 'WMG%V+TJxt$%E2w]m-xDEOnjxtS4D+V?IpaexZof}?Nxt5$hIps,'},
#     'Primary': {'36bf14ea4f946278e34f1f346fb0e7da': 'dQH0R:-V%0-BIWjY9uNF1}ShSzOE-ns.%1kC4;jEIqaL'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': 'Végzetes csütörtök',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '4431ae176c41cd7621576c6df74ef216',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2004-10-03T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': '4431ae176c41cd7621576c6df74ef216',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'Desperate Housewives S01E01',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'Path': '/series/Desperate Housewives [imdbid-tt0410975]/Season 1/Desperate Housewives S01E01.mkv',
#    'ChannelId': None,
#    'CommunityRating': 7.5,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2004,
#    'IndexNumber': 1,
#    'ParentIndexNumber': 1,
#    'IsFolder': False,
#    'Type': 'Episode',
#    'ParentLogoItemId': '645ef121ffec523b757d91458e0a3806',
#    'ParentBackdropItemId': '645ef121ffec523b757d91458e0a3806',
#    'ParentBackdropImageTags': ['73d374552ef737f2b412500135f2b53a'],
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 2,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-03-25T22:32:14.6950758Z',
#     'Played': True,
#     'Key': '73800001001',
#     'ItemId': '4431ae176c41cd7621576c6df74ef216'},
#    'SeriesName': 'Született feleségek',
#    'SeriesId': '645ef121ffec523b757d91458e0a3806',
#    'SeasonId': 'b7b015a60308c8a61333ad67619bc9bf',
#    'SeriesPrimaryImageTag': '705266a9c7913e08d528decb4df1256b',
#    'SeasonName': 'Season 1',
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': 'd137523dd2e5ae625e72347d3a1a8d3b'},
#    'BackdropImageTags': [],
#    'ParentLogoImageTag': '57edc399a9aa2ff1d861803c68385a9a',
#    'ImageBlurHashes': {'Primary': {'d137523dd2e5ae625e72347d3a1a8d3b': 'WHEBsvxZ0zRPv}%M4.Io-pkW%MaKx]S2M{s:M{s:NGofsojYkWbH',
#      '705266a9c7913e08d528decb4df1256b': 'dUL|ls$fx^-;~Wxax[kX_3V@E1x[XBMyX9tR$jxGx]NG'},
#     'Logo': {'57edc399a9aa2ff1d861803c68385a9a': 'HeLV{|s:kCxaofofj[nioL*KjFWVWBWBjZaysoj['},
#     'Thumb': {'501a785b9c852662c76c4e10d1bdf5d0': 'W~P=]5xa%g%MkCtS_Nj]kWt7WooznPWWNFWBoJoI%1s:tRayf+W='},
#     'Backdrop': {'73d374552ef737f2b412500135f2b53a': 'WbMGYC-:RPozM|xa_Mxawd%L%1%2cDs.IVt7xZoz-:xZRQkCD*Io'}},
#    'ParentThumbItemId': '645ef121ffec523b757d91458e0a3806',
#    'ParentThumbImageTag': '501a785b9c852662c76c4e10d1bdf5d0',
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': 'Ó, de lent a mélyben',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '578e56387503ef12d24fa71e38f6b423',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2004-10-10T00:00:00.0000000Z',
# ...
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'Hungarian - Default - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 6,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 17297603,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'CriticRating': 37,
#    'Path': '/movies/X-Men Origins Wolverine (2009) [imdbid-tt0458525]/trinity-x-men.origins.wolverine.1080p.mkv',
#    'OfficialRating': 'HU-16',
#    'ChannelId': None,
#    'CommunityRating': 6.286,
#    'RunTimeTicks': 64442660000,
#    'ProductionYear': 2009,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 6,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-21T14:06:30.9366366Z',
#     'Played': True,
#     'Key': '0e145ff6-588b-7cc1-b624-c370107ddd3d',
#     'ItemId': '0e145ff6588b7cc1b624c370107ddd3d'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Thumb': '2dab7dad8616387f63f994236787d3f8',
#     'Primary': '7680b3e867cea1a78110d6e406ed7d2f',
#     'Logo': 'f61ca8d56f3e3f4a31805c0f3ec62ca1'},
#    'BackdropImageTags': ['df67a06330385a2e560f0046c4c59357'],
#    'ImageBlurHashes': {'Backdrop': {'df67a06330385a2e560f0046c4c59357': 'WD7T^At70LIo={s.%Lj[M{WBs:WV9GRk-:xtM|RkD%WB-pt7RjbH'},
#     'Thumb': {'2dab7dad8616387f63f994236787d3f8': 'W65O1yxZ0MIp%Ls.xtoeNGR*kCof0fR+^%xZIoWqD*R*%LxaaeR*'},
#     'Primary': {'7680b3e867cea1a78110d6e406ed7d2f': 'dNBN7w%M00Io%hRkIVo#4oM{?b%MM{t7xaM{%1t7M_IT'},
#     'Logo': {'f61ca8d56f3e3f4a31805c0f3ec62ca1': 'HLC%BVWB00t7oeRjt6fQof?bWBIUt7fPWBofofay'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': 'X-Men: Az Ellenállás vége',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': 'a499608aa53f08ecf1e4e28ff6f7479d',
#    'HasSubtitles': True,
#    'Container': 'mkv',
#    'PremiereDate': '2006-05-24T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': 'a499608aa53f08ecf1e4e28ff6f7479d',
#      'Path': '/downloaded/X-Men.The.Last.Stand.2006.2160p.UHD.BluRay.DTS-HD.MA.6.1.HDR.x265.HuN-SnyderHD/x-men.the.last.stand.2160p-snyderhd.mkv',
#      'Type': 'Default',
#      'Container': 'mkv',
#      'Size': 26474683176,
#      'Name': 'x-men.the.last.stand.2160p-snyderhd',
#      'IsRemote': False,
#      'ETag': 'c796e0a60761194fa5861fd8ecd80442',
#      'RunTimeTicks': 62468480000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'hevc',
#        'Language': 'eng',
#        'ColorSpace': 'bt2020nc',
#        'ColorTransfer': 'smpte2084',
#        'ColorPrimaries': 'bt2020',
#        'TimeBase': '1/1000',
#        'VideoRange': 'HDR',
#        'VideoRangeType': 'HDR10',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '4K HEVC HDR',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'BitRate': 33904693,
#        'BitDepth': 10,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1600,
#        'Width': 3840,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'Main 10',
#        'Type': 'Video',
#        'AspectRatio': '2.40:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p10le',
#        'Level': 153,
#        'IsAnamorphic': False},
#       {'Codec': 'ac3',
#        'Language': 'hun',
#        'TimeBase': '1/1000',
#        'Title': 'Hungarian',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'Hungarian - Dolby Digital - 5.1 - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': '5.1',
#        'BitRate': 448000,
#        'Channels': 6,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0},
#       {'Codec': 'dts',
#        'Language': 'eng',
#        'TimeBase': '1/1000',
#        'Title': 'English',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'English - DTS-HD MA - 6.1',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': '6.1',
#        'BitRate': 4736980,
#        'BitDepth': 24,
#        'Channels': 7,
#        'SampleRate': 48000,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'DTS-HD MA',
#        'Type': 'Audio',
#        'Index': 2,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0},
#       {'Codec': 'ac3',
#        'Language': 'eng',
#        'TimeBase': '1/1000',
#        'Title': 'English',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'English - Dolby Digital - 5.1',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': '5.1',
#        'BitRate': 640000,
#        'Channels': 6,
#        'SampleRate': 48000,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Type': 'Audio',
#        'Index': 3,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0},
#       {'Codec': 'subrip',
#        'Language': 'hun',
#        'TimeBase': '1/1000',
#        'Title': 'Hungarian Forced',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'Hungarian Forced - Default - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': True,
#        'IsForced': True,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 4,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0},
#       {'Codec': 'subrip',
#        'Language': 'hun',
#        'TimeBase': '1/1000',
#        'Title': 'Hungarian',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'Hungarian - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 5,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0},
#       {'Codec': 'subrip',
#        'Language': 'eng',
#        'TimeBase': '1/1000',
#        'Title': 'English',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'English - SUBRIP',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 0,
#        'Width': 0,
#        'Type': 'Subtitle',
#        'Index': 6,
#        'IsExternal': False,
#        'IsTextSubtitleStream': True,
#        'SupportsExternalStream': True,
#        'Level': 0},
#       {'Codec': 'PGSSUB',
#        'Language': 'eng',
#        'TimeBase': '1/1000',
#        'Title': 'English',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedUndefined': 'Undefined',
#        'LocalizedDefault': 'Default',
#        'LocalizedForced': 'Forced',
#        'LocalizedExternal': 'External',
#        'LocalizedHearingImpaired': 'Hearing Impaired',
#        'DisplayTitle': 'English - PGSSUB',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'IsDefault': False,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1080,
#        'Width': 1920,
#        'Type': 'Subtitle',
#        'Index': 7,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': True,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 39729673,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'CriticRating': 56,
#    'Path': '/movies/X-Men The Last Stand (2006) [imdbid-tt0376994]/x-men.the.last.stand.2160p-snyderhd.mkv',
#    'OfficialRating': 'HU-16',
#    'ChannelId': None,
#    'CommunityRating': 6.418,
#    'RunTimeTicks': 62468480000,
#    'ProductionYear': 2006,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 2,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-20T11:51:45.1918901Z',
#     'Played': True,
#     'Key': '36668',
#     'ItemId': 'a499608aa53f08ecf1e4e28ff6f7479d'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Logo': '70f36ea3c7b89df8b0e0b8ee7b89eeea',
#     'Thumb': 'adebf2aea943227f2ff440bc4e92965b',
#     'Primary': 'd9fd40650d13c60015bf9b08247b6b27'},
#    'BackdropImageTags': ['3bd8e469799b6822296c5c4506c2e73b'],
#    'ImageBlurHashes': {'Backdrop': {'3bd8e469799b6822296c5c4506c2e73b': 'WKC%5G4TyE^+EN%No#-ptSbHo#tREO%2ShI=xuR*OsInNHNGxaWA'},
#     'Logo': {'70f36ea3c7b89df8b0e0b8ee7b89eeea': 'HmGv09IUWBWBofWBWBM{WB_NM{RjWBofWBV@RjWB'},
#     'Thumb': {'adebf2aea943227f2ff440bc4e92965b': 'WJD0Dm4TyD?bEM.8o#-ptlozo}f,9u%2bwI;%2R*cFInIoM|xaoK'},
#     'Primary': {'d9fd40650d13c60015bf9b08247b6b27': 'dKEx-M?bNHxG~VoJE1xaVrRjNG%MITIoRQxuXmM{Rjt7'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'},
#   {'Name': 'X-Men: A Kívülállók',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': 'f9467fc71a06e9af5410f02f4f8ed6e5',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2000-07-13T00:00:00.0000000Z',
#    'MediaSources': [{'Protocol': 'File',
#      'Id': 'f9467fc71a06e9af5410f02f4f8ed6e5',
#      'Path': '/placeholders/jellyfin-placeholder.mp4',
#      'Type': 'Default',
#      'Container': 'mp4',
#      'Size': 263455,
#      'Name': 'x-men.2160p-snyderhd',
#      'IsRemote': False,
#      'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#      'RunTimeTicks': 144000000,
#      'ReadAtNativeFramerate': False,
#      'IgnoreDts': False,
#      'IgnoreIndex': False,
#      'GenPtsInput': False,
#      'SupportsTranscoding': True,
#      'SupportsDirectStream': True,
#      'SupportsDirectPlay': True,
#      'IsInfiniteStream': False,
#      'UseMostCompatibleTranscodingProfile': False,
#      'RequiresOpening': False,
#      'RequiresClosing': False,
#      'RequiresLooping': False,
#      'SupportsProbing': True,
#      'VideoType': 'VideoFile',
#      'MediaStreams': [{'Codec': 'h264',
#        'CodecTag': 'avc1',
#        'Language': 'und',
#        'ColorSpace': 'bt709',
#        'ColorTransfer': 'bt709',
#        'ColorPrimaries': 'bt709',
#        'TimeBase': '1/24000',
#        'VideoRange': 'SDR',
#        'VideoRangeType': 'SDR',
#        'AudioSpatialFormat': 'None',
#        'DisplayTitle': '1080p H264 SDR',
#        'NalLengthSize': '4',
#        'IsInterlaced': False,
#        'IsAVC': True,
#        'BitRate': 137779,
#        'BitDepth': 8,
#        'RefFrames': 1,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Height': 1024,
#        'Width': 1536,
#        'AverageFrameRate': 23.976025,
#        'RealFrameRate': 23.976025,
#        'ReferenceFrameRate': 23.976025,
#        'Profile': 'High',
#        'Type': 'Video',
#        'AspectRatio': '1.5:1',
#        'Index': 0,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'PixelFormat': 'yuv420p',
#        'Level': 40,
#        'IsAnamorphic': False},
#       {'Codec': 'aac',
#        'CodecTag': 'mp4a',
#        'Language': 'und',
#        'TimeBase': '1/48000',
#        'VideoRange': 'Unknown',
#        'VideoRangeType': 'Unknown',
#        'AudioSpatialFormat': 'None',
#        'LocalizedDefault': 'Default',
#        'LocalizedExternal': 'External',
#        'DisplayTitle': 'AAC - Stereo - Default',
#        'IsInterlaced': False,
#        'IsAVC': False,
#        'ChannelLayout': 'stereo',
#        'BitRate': 2278,
#        'Channels': 2,
#        'SampleRate': 48000,
#        'IsDefault': True,
#        'IsForced': False,
#        'IsHearingImpaired': False,
#        'Profile': 'LC',
#        'Type': 'Audio',
#        'Index': 1,
#        'IsExternal': False,
#        'IsTextSubtitleStream': False,
#        'SupportsExternalStream': False,
#        'Level': 0}],
#      'MediaAttachments': [],
#      'Formats': [],
#      'Bitrate': 146363,
#      'RequiredHttpHeaders': {},
#      'TranscodingSubProtocol': 'http',
#      'DefaultAudioStreamIndex': 1,
#      'DefaultSubtitleStreamIndex': -1,
#      'HasSegments': False}],
#    'CriticRating': 82,
#    'Path': '/movies/X-Men (2000) [imdbid-tt0120903]/x-men.2160p-snyderhd.mkv',
#    'OfficialRating': 'HU-12',
#    'ChannelId': None,
#    'CommunityRating': 7,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2000,
#    'IsFolder': False,
#    'Type': 'Movie',
#    'UserData': {'PlaybackPositionTicks': 0,
#     'PlayCount': 5,
#     'IsFavorite': False,
#     'LastPlayedDate': '2026-04-10T20:29:12.4614206Z',
#     'Played': True,
#     'Key': '36657',
#     'ItemId': 'f9467fc71a06e9af5410f02f4f8ed6e5'},
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': 'abcf9bce1f2825564cd9040706d0c1fd',
#     'Thumb': '2c43bf827bb7e5962a254c8619349933',
#     'Logo': '701c61b340454860f7c342b96b443fa5'},
#    'BackdropImageTags': ['f5b1c191e8fd9e9d8ac5204ab4bfb44d'],
#    'ImageBlurHashes': {'Backdrop': {'f5b1c191e8fd9e9d8ac5204ab4bfb44d': 'WF5=eII9M|%MRjR..TITRjx]V@WY%gRPRPtRoIRktRjYRiogt6Rj'},
#     'Primary': {'abcf9bce1f2825564cd9040706d0c1fd': 'dmGR@z%M0LM|o#WXoet7RkWC%2t7offPj@aeM|jtxtoJ'},
#     'Thumb': {'2c43bf827bb7e5962a254c8619349933': 'WJAAj$kDkDt7tSR.j]a#x]t7WEbI4TWAIUWCt5jqIUWBRPNHj=ob'},
#     'Logo': {'701c61b340454860f7c342b96b443fa5': 'V37wQi^k7LE29F~q%MbGM{D%GttRR6i_Hrx[xuM{M|D%'}},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video'}],
#  'TotalRecordCount': 44,
#  'StartIndex': 0}

# %%
start = time.time()

params = {
    "IncludeItemTypes": "Movie",
    "Recursive": "true",
    #"Fields": "UserData,Id,Name,Type,ProductionYear,SeriesName,ParentIndexNumber,IndexNumber,MediaSources,Path",
    #"Filters": "IsPlayed",
}


resp = requests.get(url, headers=headers, params=params, timeout=300)
resp.raise_for_status()
data = resp.json()

end = time.time()

print(f"Total runtime of the program is {end - start} seconds")
print("Total movies:", data["TotalRecordCount"])
# Out:
# Total runtime of the program is 2.761064052581787 seconds
# Total movies: 22170

# %%
start = time.time()

params = {
    "IncludeItemTypes": "Movie",
    "Recursive": "true",
    "Fields": "UserData,Id,Name,Type,ProductionYear,SeriesName,ParentIndexNumber,IndexNumber,MediaSources,Path",
    #"Filters": "IsPlayed",
}


resp = requests.get(url, headers=headers, params=params, timeout=300)
resp.raise_for_status()
data = resp.json()

end = time.time()

print(f"Total runtime of the program is {end - start} seconds")
print("Total movies:", data["TotalRecordCount"])
# Out:
# Total runtime of the program is 0.06121087074279785 seconds
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 18
#      14
#      15 end = time.time()
#      16
#      17 print(f"Total runtime of the program is {end - start} seconds")
# ---> 18 print("Total movies:", data["TotalRecordCount"])
#
# TypeError: list indices must be integers or slices, not str

# %%
start = time.time()

params = {
    "IncludeItemTypes": "Episode",
    "Recursive": "true",
    "Fields": "UserData,Id,Name,Type,ProductionYear,SeriesName,ParentIndexNumber,IndexNumber,MediaSources,Path",
    "Filters": "IsPlayed",
}


resp = requests.get(url, headers=headers, params=params, timeout=30)
resp.raise_for_status()
data = resp.json()

end = time.time()

print(f"Total runtime of the program is {end - start} seconds")
print("Total movies:", data["TotalRecordCount"])
display(data)
# Out:
# Total runtime of the program is 0.028186798095703125 seconds
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 18
#      14
#      15 end = time.time()
#      16
#      17 print(f"Total runtime of the program is {end - start} seconds")
# ---> 18 print("Total movies:", data["TotalRecordCount"])
#      19 display(data)
#
# TypeError: list indices must be integers or slices, not str

# %%
episodes = []
start_index = 0

while True:
    params["StartIndex"] = start_index

    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()
    data = response.json()

    items = data.get("Items", [])
    if not items:
        break

    for ep in items:
        name = ep.get("Name")
        series = ep.get("SeriesName")
        season = ep.get("ParentIndexNumber")
        episode_num = ep.get("IndexNumber")
        path = ep.get("Path")

        episodes.append({
            "series": series,
            "season": season,
            "episode": episode_num,
            "name": name,
            "path": path
        })

    start_index += len(items)

# Print results
for ep in episodes:
    print(f"{ep['series']} - S{ep['season']:02}E{ep['episode']:02} - {ep['name']}")
    print(f"  Path: {ep['path']}")
# Out:
# Született feleségek - S01E01 - Végzetes csütörtök
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E01.mkv
# Született feleségek - S01E02 - Ó, de lent a mélyben
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E02.mkv
# Született feleségek - S01E03 - Szép kis látvány
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E03.mkv
# Született feleségek - S01E04 - Ki ez a nő?
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E04.mkv
# Született feleségek - S01E05 - Jöjj be, idegen!
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E05.mkv
# Született feleségek - S01E06 - Egy helyben toporogva
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E06.mkv
# Született feleségek - S01E07 - Bármi megeshet!
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E07.mkv
# Született feleségek - S01E08 - Bűnös
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E08.mkv
# Született feleségek - S01E09 - Gyanakvó elmék
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E09.mkv
# Született feleségek - S01E10 - Jöjj vissza hozzám!
#   Path: /series/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng [imdbid-tt0410975]/Season 1/Szuletett Felesegek Desperate Housewives 720p Hun Eng Subs Hun Eng S01E10.mkv
# Dóra, a felfedező - S08E01 - 1. epizód
#   Path: /series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E01.mkv
# Dóra, a felfedező - S08E02 - 2. epizód
#   Path: /series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E02.mkv
# Dóra, a felfedező - S08E03 - 3. epizód
#   Path: /series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E03.mkv
# Dóra, a felfedező - S08E04 - 4. epizód
#   Path: /series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E04.mkv
# Dóra, a felfedező - S08E05 - 5. epizód
#   Path: /series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E05.mkv

# %%
import json

# Jellyfin instant play notifier

# http://localhost/Sessions/Playing/Progress

start = time.time()

headers: dict = {
    "X-Emby-Authorization": (
        f'MediaBrowser Client="JellyfinMonitor", '
        f'Device="PythonScript", DeviceId="monitor-001", Version="1.0", Token="{api_key}"'
    ),
    "Accept": "application/json",
}


url = f"{server_url}/Sessions"

try:
    resp = requests.get(url, headers=headers, timeout=300)
    resp.raise_for_status()
    data = resp.json()
except requests.RequestException as exc:
    print("Failed to fetch items: %s", exc)

end = time.time()
print(type(data[0]))
print(data[0]['IsActive'])
print(data[0]['Id'])
print(data[0]['PlayState']['CanSeek'])
print('-'*40)

sd = 0

try:
    for dd in data:
        print(f"Attempt: {sd}")
        path = dd.get('NowPlayingItem', {}).get('Path')
        id = dd.get('NowPlayingItem', {}).get('Id')
        print(path)
        print(id)
    
        sd += 1
except Exception as e:
    print(f"Check 1 has been failed. Error: {e}")


print('-'*40)

print(f"Total runtime of the program is {end - start} seconds")
with open('jellyfin_sessions.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
    
#display(data[0])
# Out:
# <class 'dict'>
# True
# c0273a366499843aab873a9b7bf6d674
# True
# ----------------------------------------
# Attempt: 0
# /movies/Poohs Heffalump Movie (2005) [imdbid-tt0407121]/crls-poohs.heffalump.movie.1080p.mkv
# 713df22e97bfe67c4efc176773fe1114
# Attempt: 1
# /movies/hogy szaladnak a fák! mkv [imdbid-tt0133009]/hogy szaladnak a fák!.mkv
# 525f024d2ab59d90dd201690c7d5b91f
# Attempt: 2
# /movies/Apocalypse Now (1979) [imdbid-tt0078788]/Apocalypse.Now.1979.Final.Cut.2160p.UHD.BluRay.TrueHD.Atmos.7.1.DoVi-HDR.x265.HuN-TRiNiTY.mkv
# d4dd6f1dfbf907cc1f187849e2939006
# ----------------------------------------
# Total runtime of the program is 0.010654926300048828 seconds

# %%
import json

# Jellyfin instant play notifier

# http://localhost/Sessions/Playing/Progress

start = time.time()

headers: dict = {
    "X-Emby-Authorization": (
        f'MediaBrowser Client="JellyfinMonitor", '
        f'Device="PythonScript", DeviceId="monitor-001", Version="1.0", Token="{api_key}"'
    ),
    "Accept": "application/json",
}

id  = '15d4618dc3e79c4fe1590163233d141e'
url = f"{server_url}/Items/{id}"

try:
    resp = requests.get(url, headers=headers, timeout=300)
    resp.raise_for_status()
    data = resp.json()
except requests.RequestException as exc:
    print("Failed to fetch items: %s", exc)

end = time.time()

#display(json.dumps(data))
display(data)
# Out:
# Failed to fetch items: %s 400 Client Error: Bad Request for url: http://192.168.0.147:8096/Items/15d4618dc3e79c4fe1590163233d141e
# [{'PlayState': {'PositionTicks': 60008120,
#    'CanSeek': True,
#    'IsPaused': False,
#    'IsMuted': False,
#    'VolumeLevel': 100,
#    'AudioStreamIndex': 1,
#    'SubtitleStreamIndex': -1,
#    'MediaSourceId': 'e8a269e252b75edccf6f6a746d40d4fe',
#    'PlayMethod': 'DirectPlay',
#    'RepeatMode': 'RepeatNone',
#    'PlaybackOrder': 'Default'},
#   'AdditionalUsers': [],
#   'Capabilities': {'PlayableMediaTypes': ['Audio', 'Video'],
#    'SupportedCommands': ['MoveUp',
#     'MoveDown',
#     'MoveLeft',
#     'MoveRight',
#     'PageUp',
#     'PageDown',
#     'PreviousLetter',
#     'NextLetter',
#     'ToggleOsd',
#     'ToggleContextMenu',
#     'Select',
#     'Back',
#     'SendKey',
#     'SendString',
#     'GoHome',
#     'GoToSettings',
#     'VolumeUp',
#     'VolumeDown',
#     'Mute',
#     'Unmute',
#     'ToggleMute',
#     'SetVolume',
#     'SetAudioStreamIndex',
#     'SetSubtitleStreamIndex',
#     'DisplayContent',
#     'GoToSearch',
#     'DisplayMessage',
#     'SetRepeatMode',
#     'SetShuffleQueue',
#     'ChannelUp',
#     'ChannelDown',
#     'PlayMediaSource',
#     'PlayTrailers'],
#    'SupportsMediaControl': True,
#    'SupportsPersistentIdentifier': False},
#   'RemoteEndPoint': '192.168.0.112',
#   'PlayableMediaTypes': ['Audio', 'Video'],
#   'Id': 'f026207c03a0cbb4258bd8b15694ef4d',
#   'UserId': 'e3cc30114c354b68995e36c06793dedc',
#   'UserName': 'szucsiki',
#   'Client': 'Jellyfin Web',
#   'LastActivityDate': '2026-04-22T07:22:19.0072718Z',
#   'LastPlaybackCheckIn': '2026-04-22T07:22:13.0038206Z',
#   'DeviceName': 'Firefox',
#   'NowPlayingItem': {'Name': '7. epizód',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': 'e8a269e252b75edccf6f6a746d40d4fe',
#    'DateCreated': '2026-03-20T08:09:53.4329053Z',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2013-10-02T00:00:00.0000000Z',
#    'ExternalUrls': [{'Name': 'IMDb',
#      'Url': 'https://www.imdb.com/title/tt3204496'},
#     {'Name': 'TMDB',
#      'Url': 'https://www.themoviedb.org/tv/79/season/8/episode/7'}],
#    'Path': '/series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E07.mkv',
#    'EnableMediaSourceDisplay': True,
#    'ChannelId': None,
#    'Overview': 'After helping Sparky the horse feel better, Dora goes on one more ride with him before bringing him back to the barn. Help them watch out for Swiper, prickly bushes and falling rocks!',
#    'Taglines': [],
#    'Genres': [],
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2013,
#    'IndexNumber': 7,
#    'ParentIndexNumber': 8,
#    'ProviderIds': {'Imdb': 'tt3204496', 'Tvdb': '4673463'},
#    'IsHD': True,
#    'IsFolder': False,
#    'ParentId': '1640c2cb619ca731b80f629d4b447fda',
#    'Type': 'Episode',
#    'Studios': [],
#    'GenreItems': [],
#    'ParentLogoItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#    'ParentBackdropItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#    'ParentBackdropImageTags': ['578ccb194047e306a82109f209182cb4'],
#    'LocalTrailerCount': 0,
#    'SeriesName': 'Dóra, a felfedező',
#    'SeriesId': '5c57fa86871fe0c90c45629bdcd453c4',
#    'SeasonId': '1640c2cb619ca731b80f629d4b447fda',
#    'SpecialFeatureCount': 0,
#    'PrimaryImageAspectRatio': 1.7777777777777777,
#    'SeriesPrimaryImageTag': '5abd37fca61ac5014f6f8f050503b49d',
#    'SeasonName': 'Season 8',
#    'MediaStreams': [{'Codec': 'h264',
#      'CodecTag': 'avc1',
#      'Language': 'und',
#      'ColorSpace': 'bt709',
#      'ColorTransfer': 'bt709',
#      'ColorPrimaries': 'bt709',
#      'TimeBase': '1/24000',
#      'VideoRange': 'SDR',
#      'VideoRangeType': 'SDR',
#      'AudioSpatialFormat': 'None',
#      'DisplayTitle': '1080p H264 SDR',
#      'NalLengthSize': '4',
#      'IsInterlaced': False,
#      'IsAVC': True,
#      'BitRate': 137779,
#      'BitDepth': 8,
#      'RefFrames': 1,
#      'IsDefault': True,
#      'IsForced': False,
#      'IsHearingImpaired': False,
#      'Height': 1024,
#      'Width': 1536,
#      'AverageFrameRate': 23.976025,
#      'RealFrameRate': 23.976025,
#      'ReferenceFrameRate': 23.976025,
#      'Profile': 'High',
#      'Type': 'Video',
#      'AspectRatio': '1.5:1',
#      'Index': 0,
#      'IsExternal': False,
#      'IsTextSubtitleStream': False,
#      'SupportsExternalStream': False,
#      'PixelFormat': 'yuv420p',
#      'Level': 40,
#      'IsAnamorphic': False},
#     {'Codec': 'aac',
#      'CodecTag': 'mp4a',
#      'Language': 'und',
#      'TimeBase': '1/48000',
#      'VideoRange': 'Unknown',
#      'VideoRangeType': 'Unknown',
#      'AudioSpatialFormat': 'None',
#      'LocalizedDefault': 'Default',
#      'LocalizedExternal': 'External',
#      'DisplayTitle': 'AAC - Stereo - Default',
#      'IsInterlaced': False,
#      'IsAVC': False,
#      'ChannelLayout': 'stereo',
#      'BitRate': 2278,
#      'Channels': 2,
#      'SampleRate': 48000,
#      'IsDefault': True,
#      'IsForced': False,
#      'IsHearingImpaired': False,
#      'Profile': 'LC',
#      'Type': 'Audio',
#      'Index': 1,
#      'IsExternal': False,
#      'IsTextSubtitleStream': False,
#      'SupportsExternalStream': False,
#      'Level': 0}],
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': '1672556d0e640eb9c9e1a10bd5a2a8eb'},
#    'BackdropImageTags': [],
#    'ParentLogoImageTag': '86210232e0bd21a1894ea46bc9327327',
#    'ImageBlurHashes': {'Primary': {'1672556d0e640eb9c9e1a10bd5a2a8eb': 'WECHAWyqC~Gk%f%gyog4tLxZXNikIkH@$wo[R*IpyNnMboR#RQXN',
#      '5abd37fca61ac5014f6f8f050503b49d': 'dOK1t5VB5OyD^-9XS%tnCkR+#Rnm*IEdx@xvx]OUXlOs'},
#     'Logo': {'86210232e0bd21a1894ea46bc9327327': 'NLJ8V0of4nxu9FM{~q%M%Mt7WBM{4n?bRj%M%MWB'},
#     'Thumb': {'a18096b7adb70b44a86879404e24b337': 'WjNS+~QRNGWGS4X,yEROI:kXa1N1FgV{ouf$t8bcxbobjce.tQg3'},
#     'Backdrop': {'578ccb194047e306a82109f209182cb4': 'WIH:2Et$5i}bzUyF_1Iok@%3VstUB|IS-XX8OX%N?^nzxGrWRhtm'}},
#    'SeriesStudio': 'Nickelodeon',
#    'ParentThumbItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#    'ParentThumbImageTag': 'a18096b7adb70b44a86879404e24b337',
#    'Chapters': [],
#    'Trickplay': {},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video',
#    'Width': 1536,
#    'Height': 1024},
#   'DeviceId': 'TW96aWxsYS81LjAgKFgxMTsgTGludXggeDg2XzY0OyBydjoxNDguMCkgR2Vja28vMjAxMDAxMDEgRmlyZWZveC8xNDguMHwxNzczOTk0NTIwNDY0',
#   'ApplicationVersion': '10.11.8',
#   'IsActive': True,
#   'SupportsMediaControl': True,
#   'SupportsRemoteControl': True,
#   'NowPlayingQueue': [{'Id': '3b5e044eddd786a34a8089c2b0c2f8a8',
#     'PlaylistItemId': 'playlistItem0'},
#    {'Id': 'e8a269e252b75edccf6f6a746d40d4fe',
#     'PlaylistItemId': 'playlistItem1'},
#    {'Id': '7b7cb25f481ee25f975ea58fbb31046b',
#     'PlaylistItemId': 'playlistItem2'},
#    {'Id': 'ed0dc8d99452aba9618ff60e50c4220d',
#     'PlaylistItemId': 'playlistItem3'},
#    {'Id': '5de9516e830cefc18a0458248338fd3e',
#     'PlaylistItemId': 'playlistItem4'},
#    {'Id': 'a1f7a52b5d9515fce20be3f85105db20',
#     'PlaylistItemId': 'playlistItem5'},
#    {'Id': '86782445997c0bdefa5e00a9670a0032',
#     'PlaylistItemId': 'playlistItem6'},
#    {'Id': '28b8c3b2b10ce54fb547b684f8a2fa15',
#     'PlaylistItemId': 'playlistItem7'},
#    {'Id': 'c1aa9c73e80c39d8c405eaff72fb3559',
#     'PlaylistItemId': 'playlistItem8'},
#    {'Id': '52b914998a7c6d69e2842c703d1fda26',
#     'PlaylistItemId': 'playlistItem9'},
#    {'Id': 'ca1cceded18e306edd04a2166f6f1b09',
#     'PlaylistItemId': 'playlistItem10'},
#    {'Id': '34b91c37d0505e403056875488fbe558',
#     'PlaylistItemId': 'playlistItem11'},
#    {'Id': '369ef6ddad756cc1656f11b141a273e1',
#     'PlaylistItemId': 'playlistItem12'},
#    {'Id': 'b9b15f21b65c98088f0ea0083ffd319f',
#     'PlaylistItemId': 'playlistItem13'}],
#   'NowPlayingQueueFullItems': [{'Name': '6. epizód',
#     'ServerId': '5044f8c0502743b09777364723ddc2e0',
#     'Id': '3b5e044eddd786a34a8089c2b0c2f8a8',
#     'Etag': '68701f291bd51117250e4d85b9767c14',
#     'DateCreated': '2026-03-20T08:09:53.4329053Z',
#     'CanDelete': True,
#     'CanDownload': True,
#     'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#     'SortName': '008 - 0006 - 6. epizód',
#     'PremiereDate': '2013-09-30T00:00:00.0000000Z',
#     'ExternalUrls': [{'Name': 'TMDB',
#       'Url': 'https://www.themoviedb.org/tv/79/season/8/episode/6'}],
#     'MediaSources': [{'Protocol': 'File',
#       'Id': '3b5e044eddd786a34a8089c2b0c2f8a8',
#       'Path': '/placeholders/jellyfin-placeholder.mp4',
#       'Type': 'Default',
#       'Container': 'mp4',
#       'Size': 263455,
#       'Name': 'Dora The Explorer S08E06',
#       'IsRemote': False,
#       'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#       'RunTimeTicks': 144000000,
#       'ReadAtNativeFramerate': False,
#       'IgnoreDts': False,
#       'IgnoreIndex': False,
#       'GenPtsInput': False,
#       'SupportsTranscoding': True,
#       'SupportsDirectStream': True,
#       'SupportsDirectPlay': True,
#       'IsInfiniteStream': False,
#       'UseMostCompatibleTranscodingProfile': False,
#       'RequiresOpening': False,
#       'RequiresClosing': False,
#       'RequiresLooping': False,
#       'SupportsProbing': True,
#       'VideoType': 'VideoFile',
#       'MediaStreams': [{'Codec': 'h264',
#         'CodecTag': 'avc1',
#         'Language': 'und',
#         'ColorSpace': 'bt709',
#         'ColorTransfer': 'bt709',
#         'ColorPrimaries': 'bt709',
#         'TimeBase': '1/24000',
#         'VideoRange': 'SDR',
#         'VideoRangeType': 'SDR',
#         'AudioSpatialFormat': 'None',
#         'DisplayTitle': '1080p H264 SDR',
#         'NalLengthSize': '4',
#         'IsInterlaced': False,
#         'IsAVC': True,
#         'BitRate': 137779,
#         'BitDepth': 8,
#         'RefFrames': 1,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Height': 1024,
#         'Width': 1536,
#         'AverageFrameRate': 23.976025,
#         'RealFrameRate': 23.976025,
#         'ReferenceFrameRate': 23.976025,
#         'Profile': 'High',
#         'Type': 'Video',
#         'AspectRatio': '1.5:1',
#         'Index': 0,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'PixelFormat': 'yuv420p',
#         'Level': 40,
#         'IsAnamorphic': False},
#        {'Codec': 'aac',
#         'CodecTag': 'mp4a',
#         'Language': 'und',
#         'TimeBase': '1/48000',
#         'VideoRange': 'Unknown',
#         'VideoRangeType': 'Unknown',
#         'AudioSpatialFormat': 'None',
#         'LocalizedDefault': 'Default',
#         'LocalizedExternal': 'External',
#         'DisplayTitle': 'AAC - Stereo - Default',
#         'IsInterlaced': False,
#         'IsAVC': False,
#         'ChannelLayout': 'stereo',
#         'BitRate': 2278,
#         'Channels': 2,
#         'SampleRate': 48000,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Profile': 'LC',
#         'Type': 'Audio',
#         'Index': 1,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'Level': 0}],
#       'MediaAttachments': [],
#       'Formats': [],
#       'Bitrate': 146363,
#       'RequiredHttpHeaders': {},
#       'TranscodingSubProtocol': 'http',
#       'HasSegments': False}],
#     'Path': '/series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E06.mkv',
#     'EnableMediaSourceDisplay': True,
#     'ChannelId': None,
#     'Taglines': [],
#     'Genres': [],
#     'RunTimeTicks': 144000000,
#     'ProductionYear': 2013,
#     'IndexNumber': 6,
#     'ParentIndexNumber': 8,
#     'RemoteTrailers': [],
#     'ProviderIds': {'Tvdb': '4673462'},
#     'IsHD': True,
#     'IsFolder': False,
#     'ParentId': '1640c2cb619ca731b80f629d4b447fda',
#     'Type': 'Episode',
#     'People': [{'Name': 'Kathleen Herles',
#       'Id': 'a6487ed0a27471ce7d8ceb47352d05ad',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8fccb6f8036aec52eb6505173767447d',
#       'ImageBlurHashes': {'Primary': {'8fccb6f8036aec52eb6505173767447d': 'dNFXegt70#NG%MWWE2WBtlNH$MjsgObHwIWqx]kCRjoJ'}}},
#      {'Name': 'Marc Weiner',
#       'Id': '201a02f6a42d59bae6025817e908acca',
#       'Role': 'Map / Swiper (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8ecd13895d0860586929a6549d3f3e98',
#       'ImageBlurHashes': {'Primary': {'8ecd13895d0860586929a6549d3f3e98': 'dVF4_.-o0gIp$zj?RjoJ9uNHxaWXM|WVoybHIpWVxas:'}}},
#      {'Name': 'Caitlin Sanchez',
#       'Id': '63be2715c1ff4d23c2296f83e3cfa78d',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Ashley Flemming',
#       'Id': '5b14b4cfac799d67bea446da50e69f5e',
#       'Role': 'Isa (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Jacob Medrano',
#       'Id': '8f2a6dfc95c52e60cf9d0f3489cb3fb8',
#       'Role': 'Diego (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Alexandria Suarez',
#       'Id': 'a98b972f3d05f3fa21904ad9ab8c61ca',
#       'Role': 'Backpack (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': 'f517961d8a862e075b1e930541a5ef72',
#       'ImageBlurHashes': {'Primary': {'f517961d8a862e075b1e930541a5ef72': 'dLCr+S$j0|V]5kNt%1xtOUxt-oS2JjR*o{R*?GofI:WC'}}},
#      {'Name': 'Jose Zelaya',
#       'Id': 'ef9bc1425ff59d71cd69db672a42b2c9',
#       'Role': 'Tico (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Dolly Peter Lopes',
#       'Id': '036f25b6a61fffa050c93d8d023c13a5',
#       'Role': 'Dora (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '4acecb330a908445cec808e9a489cfdd',
#       'ImageBlurHashes': {'Primary': {'4acecb330a908445cec808e9a489cfdd': 'dLHmisrC0#CR0JTxENIAXmIU$Nw{RR$+%1SzFxIp$%%2'}}},
#      {'Name': 'Fatima Ptacek',
#       'Id': 'e5a17093c5c74851fd4c2751a2d0d90a',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '7b8e66676a30db640504e8a7097eb353',
#       'ImageBlurHashes': {'Primary': {'7b8e66676a30db640504e8a7097eb353': 'daFr3J-p0fNI9|S4xaR,bcj[%2xaIpRkofjuWYWBs.s:'}}}],
#     'Studios': [],
#     'GenreItems': [],
#     'ParentLogoItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropImageTags': ['578ccb194047e306a82109f209182cb4'],
#     'LocalTrailerCount': 0,
#     'SeriesName': 'Dóra, a felfedező',
#     'SeriesId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'SeasonId': '1640c2cb619ca731b80f629d4b447fda',
#     'SpecialFeatureCount': 0,
#     'DisplayPreferencesId': '26dd4a82b00c839c498471cdba80a99c',
#     'Tags': [],
#     'PrimaryImageAspectRatio': 1.7777777777777777,
#     'SeriesPrimaryImageTag': '5abd37fca61ac5014f6f8f050503b49d',
#     'SeasonName': 'Season 8',
#     'MediaStreams': [{'Codec': 'h264',
#       'CodecTag': 'avc1',
#       'Language': 'und',
#       'ColorSpace': 'bt709',
#       'ColorTransfer': 'bt709',
#       'ColorPrimaries': 'bt709',
#       'TimeBase': '1/24000',
#       'VideoRange': 'SDR',
#       'VideoRangeType': 'SDR',
#       'AudioSpatialFormat': 'None',
#       'DisplayTitle': '1080p H264 SDR',
#       'NalLengthSize': '4',
#       'IsInterlaced': False,
#       'IsAVC': True,
#       'BitRate': 137779,
#       'BitDepth': 8,
#       'RefFrames': 1,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Height': 1024,
#       'Width': 1536,
#       'AverageFrameRate': 23.976025,
#       'RealFrameRate': 23.976025,
#       'ReferenceFrameRate': 23.976025,
#       'Profile': 'High',
#       'Type': 'Video',
#       'AspectRatio': '1.5:1',
#       'Index': 0,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'PixelFormat': 'yuv420p',
#       'Level': 40,
#       'IsAnamorphic': False},
#      {'Codec': 'aac',
#       'CodecTag': 'mp4a',
#       'Language': 'und',
#       'TimeBase': '1/48000',
#       'VideoRange': 'Unknown',
#       'VideoRangeType': 'Unknown',
#       'AudioSpatialFormat': 'None',
#       'LocalizedDefault': 'Default',
#       'LocalizedExternal': 'External',
#       'DisplayTitle': 'AAC - Stereo - Default',
#       'IsInterlaced': False,
#       'IsAVC': False,
#       'ChannelLayout': 'stereo',
#       'BitRate': 2278,
#       'Channels': 2,
#       'SampleRate': 48000,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Profile': 'LC',
#       'Type': 'Audio',
#       'Index': 1,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'Level': 0}],
#     'VideoType': 'VideoFile',
#     'ImageTags': {'Primary': '8713534faa6b8d0841b2f88ebec93838'},
#     'BackdropImageTags': [],
#     'ParentLogoImageTag': '86210232e0bd21a1894ea46bc9327327',
#     'ImageBlurHashes': {'Primary': {'8713534faa6b8d0841b2f88ebec93838': 'WfJca9xR,B$|oJu0CaabWSogkBO-#LRPI:V[WBbJtURiRlkSoNeV',
#       '5abd37fca61ac5014f6f8f050503b49d': 'dOK1t5VB5OyD^-9XS%tnCkR+#Rnm*IEdx@xvx]OUXlOs'},
#      'Logo': {'86210232e0bd21a1894ea46bc9327327': 'NLJ8V0of4nxu9FM{~q%M%Mt7WBM{4n?bRj%M%MWB'},
#      'Thumb': {'a18096b7adb70b44a86879404e24b337': 'WjNS+~QRNGWGS4X,yEROI:kXa1N1FgV{ouf$t8bcxbobjce.tQg3'},
#      'Backdrop': {'578ccb194047e306a82109f209182cb4': 'WIH:2Et$5i}bzUyF_1Iok@%3VstUB|IS-XX8OX%N?^nzxGrWRhtm'}},
#     'SeriesStudio': 'Nickelodeon',
#     'ParentThumbItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentThumbImageTag': 'a18096b7adb70b44a86879404e24b337',
#     'Chapters': [],
#     'Trickplay': {},
#     'LocationType': 'FileSystem',
#     'MediaType': 'Video',
#     'LockedFields': [],
#     'LockData': False,
#     'Width': 1536,
#     'Height': 1024},
#    {'Name': '7. epizód',
#     'ServerId': '5044f8c0502743b09777364723ddc2e0',
#     'Id': 'e8a269e252b75edccf6f6a746d40d4fe',
#     'Etag': '8ea91016dc23046e49e7af76e6d33a4d',
#     'DateCreated': '2026-03-20T08:09:53.4329053Z',
#     'CanDelete': True,
#     'CanDownload': True,
#     'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#     'SortName': '008 - 0007 - 7. epizód',
#     'PremiereDate': '2013-10-02T00:00:00.0000000Z',
#     'ExternalUrls': [{'Name': 'IMDb',
#       'Url': 'https://www.imdb.com/title/tt3204496'},
#      {'Name': 'TMDB',
#       'Url': 'https://www.themoviedb.org/tv/79/season/8/episode/7'}],
#     'MediaSources': [{'Protocol': 'File',
#       'Id': 'e8a269e252b75edccf6f6a746d40d4fe',
#       'Path': '/placeholders/jellyfin-placeholder.mp4',
#       'Type': 'Default',
#       'Container': 'mp4',
#       'Size': 263455,
#       'Name': 'Dora The Explorer S08E07',
#       'IsRemote': False,
#       'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#       'RunTimeTicks': 144000000,
#       'ReadAtNativeFramerate': False,
#       'IgnoreDts': False,
#       'IgnoreIndex': False,
#       'GenPtsInput': False,
#       'SupportsTranscoding': True,
#       'SupportsDirectStream': True,
#       'SupportsDirectPlay': True,
#       'IsInfiniteStream': False,
#       'UseMostCompatibleTranscodingProfile': False,
#       'RequiresOpening': False,
#       'RequiresClosing': False,
#       'RequiresLooping': False,
#       'SupportsProbing': True,
#       'VideoType': 'VideoFile',
#       'MediaStreams': [{'Codec': 'h264',
#         'CodecTag': 'avc1',
#         'Language': 'und',
#         'ColorSpace': 'bt709',
#         'ColorTransfer': 'bt709',
#         'ColorPrimaries': 'bt709',
#         'TimeBase': '1/24000',
#         'VideoRange': 'SDR',
#         'VideoRangeType': 'SDR',
#         'AudioSpatialFormat': 'None',
#         'DisplayTitle': '1080p H264 SDR',
#         'NalLengthSize': '4',
#         'IsInterlaced': False,
#         'IsAVC': True,
#         'BitRate': 137779,
#         'BitDepth': 8,
#         'RefFrames': 1,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Height': 1024,
#         'Width': 1536,
#         'AverageFrameRate': 23.976025,
#         'RealFrameRate': 23.976025,
#         'ReferenceFrameRate': 23.976025,
#         'Profile': 'High',
#         'Type': 'Video',
#         'AspectRatio': '1.5:1',
#         'Index': 0,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'PixelFormat': 'yuv420p',
#         'Level': 40,
#         'IsAnamorphic': False},
#        {'Codec': 'aac',
#         'CodecTag': 'mp4a',
#         'Language': 'und',
#         'TimeBase': '1/48000',
#         'VideoRange': 'Unknown',
#         'VideoRangeType': 'Unknown',
#         'AudioSpatialFormat': 'None',
#         'LocalizedDefault': 'Default',
#         'LocalizedExternal': 'External',
#         'DisplayTitle': 'AAC - Stereo - Default',
#         'IsInterlaced': False,
#         'IsAVC': False,
#         'ChannelLayout': 'stereo',
#         'BitRate': 2278,
#         'Channels': 2,
#         'SampleRate': 48000,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Profile': 'LC',
#         'Type': 'Audio',
#         'Index': 1,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'Level': 0}],
#       'MediaAttachments': [],
#       'Formats': [],
#       'Bitrate': 146363,
#       'RequiredHttpHeaders': {},
#       'TranscodingSubProtocol': 'http',
#       'HasSegments': False}],
#     'Path': '/series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E07.mkv',
#     'EnableMediaSourceDisplay': True,
#     'ChannelId': None,
#     'Overview': 'After helping Sparky the horse feel better, Dora goes on one more ride with him before bringing him back to the barn. Help them watch out for Swiper, prickly bushes and falling rocks!',
#     'Taglines': [],
#     'Genres': [],
#     'RunTimeTicks': 144000000,
#     'ProductionYear': 2013,
#     'IndexNumber': 7,
#     'ParentIndexNumber': 8,
#     'RemoteTrailers': [],
#     'ProviderIds': {'Imdb': 'tt3204496', 'Tvdb': '4673463'},
#     'IsHD': True,
#     'IsFolder': False,
#     'ParentId': '1640c2cb619ca731b80f629d4b447fda',
#     'Type': 'Episode',
#     'People': [{'Name': 'Kathleen Herles',
#       'Id': 'a6487ed0a27471ce7d8ceb47352d05ad',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8fccb6f8036aec52eb6505173767447d',
#       'ImageBlurHashes': {'Primary': {'8fccb6f8036aec52eb6505173767447d': 'dNFXegt70#NG%MWWE2WBtlNH$MjsgObHwIWqx]kCRjoJ'}}},
#      {'Name': 'Marc Weiner',
#       'Id': '201a02f6a42d59bae6025817e908acca',
#       'Role': 'Map / Swiper (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8ecd13895d0860586929a6549d3f3e98',
#       'ImageBlurHashes': {'Primary': {'8ecd13895d0860586929a6549d3f3e98': 'dVF4_.-o0gIp$zj?RjoJ9uNHxaWXM|WVoybHIpWVxas:'}}},
#      {'Name': 'Caitlin Sanchez',
#       'Id': '63be2715c1ff4d23c2296f83e3cfa78d',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Ashley Flemming',
#       'Id': '5b14b4cfac799d67bea446da50e69f5e',
#       'Role': 'Isa (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Jacob Medrano',
#       'Id': '8f2a6dfc95c52e60cf9d0f3489cb3fb8',
#       'Role': 'Diego (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Alexandria Suarez',
#       'Id': 'a98b972f3d05f3fa21904ad9ab8c61ca',
#       'Role': 'Backpack (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': 'f517961d8a862e075b1e930541a5ef72',
#       'ImageBlurHashes': {'Primary': {'f517961d8a862e075b1e930541a5ef72': 'dLCr+S$j0|V]5kNt%1xtOUxt-oS2JjR*o{R*?GofI:WC'}}},
#      {'Name': 'Jose Zelaya',
#       'Id': 'ef9bc1425ff59d71cd69db672a42b2c9',
#       'Role': 'Tico (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Dolly Peter Lopes',
#       'Id': '036f25b6a61fffa050c93d8d023c13a5',
#       'Role': 'Dora (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '4acecb330a908445cec808e9a489cfdd',
#       'ImageBlurHashes': {'Primary': {'4acecb330a908445cec808e9a489cfdd': 'dLHmisrC0#CR0JTxENIAXmIU$Nw{RR$+%1SzFxIp$%%2'}}},
#      {'Name': 'Fatima Ptacek',
#       'Id': 'e5a17093c5c74851fd4c2751a2d0d90a',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '7b8e66676a30db640504e8a7097eb353',
#       'ImageBlurHashes': {'Primary': {'7b8e66676a30db640504e8a7097eb353': 'daFr3J-p0fNI9|S4xaR,bcj[%2xaIpRkofjuWYWBs.s:'}}}],
#     'Studios': [],
#     'GenreItems': [],
#     'ParentLogoItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropImageTags': ['578ccb194047e306a82109f209182cb4'],
#     'LocalTrailerCount': 0,
#     'SeriesName': 'Dóra, a felfedező',
#     'SeriesId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'SeasonId': '1640c2cb619ca731b80f629d4b447fda',
#     'SpecialFeatureCount': 0,
#     'DisplayPreferencesId': '26dd4a82b00c839c498471cdba80a99c',
#     'Tags': [],
#     'PrimaryImageAspectRatio': 1.7777777777777777,
#     'SeriesPrimaryImageTag': '5abd37fca61ac5014f6f8f050503b49d',
#     'SeasonName': 'Season 8',
#     'MediaStreams': [{'Codec': 'h264',
#       'CodecTag': 'avc1',
#       'Language': 'und',
#       'ColorSpace': 'bt709',
#       'ColorTransfer': 'bt709',
#       'ColorPrimaries': 'bt709',
#       'TimeBase': '1/24000',
#       'VideoRange': 'SDR',
#       'VideoRangeType': 'SDR',
#       'AudioSpatialFormat': 'None',
#       'DisplayTitle': '1080p H264 SDR',
#       'NalLengthSize': '4',
#       'IsInterlaced': False,
#       'IsAVC': True,
#       'BitRate': 137779,
#       'BitDepth': 8,
#       'RefFrames': 1,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Height': 1024,
#       'Width': 1536,
#       'AverageFrameRate': 23.976025,
#       'RealFrameRate': 23.976025,
#       'ReferenceFrameRate': 23.976025,
#       'Profile': 'High',
#       'Type': 'Video',
#       'AspectRatio': '1.5:1',
#       'Index': 0,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'PixelFormat': 'yuv420p',
#       'Level': 40,
#       'IsAnamorphic': False},
#      {'Codec': 'aac',
#       'CodecTag': 'mp4a',
#       'Language': 'und',
#       'TimeBase': '1/48000',
#       'VideoRange': 'Unknown',
#       'VideoRangeType': 'Unknown',
#       'AudioSpatialFormat': 'None',
#       'LocalizedDefault': 'Default',
#       'LocalizedExternal': 'External',
#       'DisplayTitle': 'AAC - Stereo - Default',
#       'IsInterlaced': False,
#       'IsAVC': False,
#       'ChannelLayout': 'stereo',
#       'BitRate': 2278,
#       'Channels': 2,
#       'SampleRate': 48000,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Profile': 'LC',
#       'Type': 'Audio',
#       'Index': 1,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'Level': 0}],
#     'VideoType': 'VideoFile',
#     'ImageTags': {'Primary': '1672556d0e640eb9c9e1a10bd5a2a8eb'},
#     'BackdropImageTags': [],
#     'ParentLogoImageTag': '86210232e0bd21a1894ea46bc9327327',
#     'ImageBlurHashes': {'Primary': {'1672556d0e640eb9c9e1a10bd5a2a8eb': 'WECHAWyqC~Gk%f%gyog4tLxZXNikIkH@$wo[R*IpyNnMboR#RQXN',
#       '5abd37fca61ac5014f6f8f050503b49d': 'dOK1t5VB5OyD^-9XS%tnCkR+#Rnm*IEdx@xvx]OUXlOs'},
#      'Logo': {'86210232e0bd21a1894ea46bc9327327': 'NLJ8V0of4nxu9FM{~q%M%Mt7WBM{4n?bRj%M%MWB'},
#      'Thumb': {'a18096b7adb70b44a86879404e24b337': 'WjNS+~QRNGWGS4X,yEROI:kXa1N1FgV{ouf$t8bcxbobjce.tQg3'},
#      'Backdrop': {'578ccb194047e306a82109f209182cb4': 'WIH:2Et$5i}bzUyF_1Iok@%3VstUB|IS-XX8OX%N?^nzxGrWRhtm'}},
#     'SeriesStudio': 'Nickelodeon',
#     'ParentThumbItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentThumbImageTag': 'a18096b7adb70b44a86879404e24b337',
#     'Chapters': [],
#     'Trickplay': {},
#     'LocationType': 'FileSystem',
#     'MediaType': 'Video',
#     'LockedFields': [],
#     'LockData': False,
#     'Width': 1536,
#     'Height': 1024},
#    {'Name': '8. epizód',
#     'ServerId': '5044f8c0502743b09777364723ddc2e0',
#     'Id': '7b7cb25f481ee25f975ea58fbb31046b',
#     'Etag': 'dd6e1f372b283a408b1c7fb5c8c5648b',
#     'DateCreated': '2026-03-20T08:09:53.4329053Z',
#     'CanDelete': True,
#     'CanDownload': True,
#     'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#     'SortName': '008 - 0008 - 8. epizód',
#     'PremiereDate': '2013-10-28T00:00:00.0000000Z',
#     'ExternalUrls': [{'Name': 'IMDb',
#       'Url': 'https://www.imdb.com/title/tt5741758'},
#      {'Name': 'TMDB',
#       'Url': 'https://www.themoviedb.org/tv/79/season/8/episode/8'}],
#     'MediaSources': [{'Protocol': 'File',
#       'Id': '7b7cb25f481ee25f975ea58fbb31046b',
#       'Path': '/placeholders/jellyfin-placeholder.mp4',
#       'Type': 'Default',
#       'Container': 'mp4',
#       'Size': 263455,
#       'Name': 'Dora The Explorer S08E08',
#       'IsRemote': False,
#       'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#       'RunTimeTicks': 144000000,
#       'ReadAtNativeFramerate': False,
#       'IgnoreDts': False,
#       'IgnoreIndex': False,
#       'GenPtsInput': False,
#       'SupportsTranscoding': True,
#       'SupportsDirectStream': True,
#       'SupportsDirectPlay': True,
#       'IsInfiniteStream': False,
#       'UseMostCompatibleTranscodingProfile': False,
#       'RequiresOpening': False,
#       'RequiresClosing': False,
#       'RequiresLooping': False,
#       'SupportsProbing': True,
#       'VideoType': 'VideoFile',
#       'MediaStreams': [{'Codec': 'h264',
#         'CodecTag': 'avc1',
#         'Language': 'und',
#         'ColorSpace': 'bt709',
#         'ColorTransfer': 'bt709',
#         'ColorPrimaries': 'bt709',
#         'TimeBase': '1/24000',
#         'VideoRange': 'SDR',
#         'VideoRangeType': 'SDR',
#         'AudioSpatialFormat': 'None',
#         'DisplayTitle': '1080p H264 SDR',
#         'NalLengthSize': '4',
#         'IsInterlaced': False,
#         'IsAVC': True,
#         'BitRate': 137779,
#         'BitDepth': 8,
#         'RefFrames': 1,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Height': 1024,
#         'Width': 1536,
#         'AverageFrameRate': 23.976025,
#         'RealFrameRate': 23.976025,
#         'ReferenceFrameRate': 23.976025,
#         'Profile': 'High',
#         'Type': 'Video',
#         'AspectRatio': '1.5:1',
#         'Index': 0,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'PixelFormat': 'yuv420p',
#         'Level': 40,
#         'IsAnamorphic': False},
#        {'Codec': 'aac',
#         'CodecTag': 'mp4a',
#         'Language': 'und',
#         'TimeBase': '1/48000',
#         'VideoRange': 'Unknown',
#         'VideoRangeType': 'Unknown',
#         'AudioSpatialFormat': 'None',
#         'LocalizedDefault': 'Default',
#         'LocalizedExternal': 'External',
#         'DisplayTitle': 'AAC - Stereo - Default',
#         'IsInterlaced': False,
#         'IsAVC': False,
#         'ChannelLayout': 'stereo',
#         'BitRate': 2278,
#         'Channels': 2,
#         'SampleRate': 48000,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Profile': 'LC',
#         'Type': 'Audio',
#         'Index': 1,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'Level': 0}],
#       'MediaAttachments': [],
#       'Formats': [],
#       'Bitrate': 146363,
#       'RequiredHttpHeaders': {},
#       'TranscodingSubProtocol': 'http',
#       'HasSegments': False}],
#     'Path': '/series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E08.mkv',
#     'EnableMediaSourceDisplay': True,
#     'ChannelId': None,
#     'Overview': "It's time for the Rainforest Talent Show, but first Dora and Boots have to rescue Benny so he can tell his jokes in the show.",
#     'Taglines': [],
#     'Genres': [],
#     'RunTimeTicks': 144000000,
#     'ProductionYear': 2013,
#     'IndexNumber': 8,
#     'ParentIndexNumber': 8,
#     'RemoteTrailers': [],
#     'ProviderIds': {'Imdb': 'tt5741758', 'Tvdb': '4697421'},
#     'IsHD': True,
#     'IsFolder': False,
#     'ParentId': '1640c2cb619ca731b80f629d4b447fda',
#     'Type': 'Episode',
#     'People': [{'Name': 'Kathleen Herles',
#       'Id': 'a6487ed0a27471ce7d8ceb47352d05ad',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8fccb6f8036aec52eb6505173767447d',
#       'ImageBlurHashes': {'Primary': {'8fccb6f8036aec52eb6505173767447d': 'dNFXegt70#NG%MWWE2WBtlNH$MjsgObHwIWqx]kCRjoJ'}}},
#      {'Name': 'Marc Weiner',
#       'Id': '201a02f6a42d59bae6025817e908acca',
#       'Role': 'Map / Swiper (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8ecd13895d0860586929a6549d3f3e98',
#       'ImageBlurHashes': {'Primary': {'8ecd13895d0860586929a6549d3f3e98': 'dVF4_.-o0gIp$zj?RjoJ9uNHxaWXM|WVoybHIpWVxas:'}}},
#      {'Name': 'Caitlin Sanchez',
#       'Id': '63be2715c1ff4d23c2296f83e3cfa78d',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Ashley Flemming',
#       'Id': '5b14b4cfac799d67bea446da50e69f5e',
#       'Role': 'Isa (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Jacob Medrano',
#       'Id': '8f2a6dfc95c52e60cf9d0f3489cb3fb8',
#       'Role': 'Diego (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Alexandria Suarez',
#       'Id': 'a98b972f3d05f3fa21904ad9ab8c61ca',
#       'Role': 'Backpack (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': 'f517961d8a862e075b1e930541a5ef72',
#       'ImageBlurHashes': {'Primary': {'f517961d8a862e075b1e930541a5ef72': 'dLCr+S$j0|V]5kNt%1xtOUxt-oS2JjR*o{R*?GofI:WC'}}},
#      {'Name': 'Jose Zelaya',
#       'Id': 'ef9bc1425ff59d71cd69db672a42b2c9',
#       'Role': 'Tico (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Dolly Peter Lopes',
#       'Id': '036f25b6a61fffa050c93d8d023c13a5',
#       'Role': 'Dora (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '4acecb330a908445cec808e9a489cfdd',
#       'ImageBlurHashes': {'Primary': {'4acecb330a908445cec808e9a489cfdd': 'dLHmisrC0#CR0JTxENIAXmIU$Nw{RR$+%1SzFxIp$%%2'}}},
#      {'Name': 'Fatima Ptacek',
#       'Id': 'e5a17093c5c74851fd4c2751a2d0d90a',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '7b8e66676a30db640504e8a7097eb353',
#       'ImageBlurHashes': {'Primary': {'7b8e66676a30db640504e8a7097eb353': 'daFr3J-p0fNI9|S4xaR,bcj[%2xaIpRkofjuWYWBs.s:'}}}],
#     'Studios': [],
#     'GenreItems': [],
#     'ParentLogoItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropImageTags': ['578ccb194047e306a82109f209182cb4'],
#     'LocalTrailerCount': 0,
#     'SeriesName': 'Dóra, a felfedező',
#     'SeriesId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'SeasonId': '1640c2cb619ca731b80f629d4b447fda',
#     'SpecialFeatureCount': 0,
#     'DisplayPreferencesId': '26dd4a82b00c839c498471cdba80a99c',
#     'Tags': [],
#     'PrimaryImageAspectRatio': 1.7777777777777777,
#     'SeriesPrimaryImageTag': '5abd37fca61ac5014f6f8f050503b49d',
#     'SeasonName': 'Season 8',
#     'MediaStreams': [{'Codec': 'h264',
#       'CodecTag': 'avc1',
#       'Language': 'und',
#       'ColorSpace': 'bt709',
#       'ColorTransfer': 'bt709',
#       'ColorPrimaries': 'bt709',
#       'TimeBase': '1/24000',
#       'VideoRange': 'SDR',
#       'VideoRangeType': 'SDR',
#       'AudioSpatialFormat': 'None',
#       'DisplayTitle': '1080p H264 SDR',
#       'NalLengthSize': '4',
#       'IsInterlaced': False,
#       'IsAVC': True,
#       'BitRate': 137779,
#       'BitDepth': 8,
#       'RefFrames': 1,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Height': 1024,
#       'Width': 1536,
#       'AverageFrameRate': 23.976025,
#       'RealFrameRate': 23.976025,
#       'ReferenceFrameRate': 23.976025,
#       'Profile': 'High',
#       'Type': 'Video',
#       'AspectRatio': '1.5:1',
#       'Index': 0,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'PixelFormat': 'yuv420p',
#       'Level': 40,
#       'IsAnamorphic': False},
#      {'Codec': 'aac',
#       'CodecTag': 'mp4a',
#       'Language': 'und',
#       'TimeBase': '1/48000',
#       'VideoRange': 'Unknown',
#       'VideoRangeType': 'Unknown',
#       'AudioSpatialFormat': 'None',
#       'LocalizedDefault': 'Default',
#       'LocalizedExternal': 'External',
#       'DisplayTitle': 'AAC - Stereo - Default',
#       'IsInterlaced': False,
#       'IsAVC': False,
#       'ChannelLayout': 'stereo',
#       'BitRate': 2278,
#       'Channels': 2,
#       'SampleRate': 48000,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Profile': 'LC',
#       'Type': 'Audio',
#       'Index': 1,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'Level': 0}],
#     'VideoType': 'VideoFile',
#     'ImageTags': {'Primary': 'd55e7f72721afdfd2268ee1e7600929b'},
#     'BackdropImageTags': [],
#     'ParentLogoImageTag': '86210232e0bd21a1894ea46bc9327327',
#     'ImageBlurHashes': {'Primary': {'d55e7f72721afdfd2268ee1e7600929b': 'WSIELzyFo~=YKkt,19O[S%VXpIWZEKWZs.I.VXvzspaiWCt8nNaJ',
#       '5abd37fca61ac5014f6f8f050503b49d': 'dOK1t5VB5OyD^-9XS%tnCkR+#Rnm*IEdx@xvx]OUXlOs'},
#      'Logo': {'86210232e0bd21a1894ea46bc9327327': 'NLJ8V0of4nxu9FM{~q%M%Mt7WBM{4n?bRj%M%MWB'},
#      'Thumb': {'a18096b7adb70b44a86879404e24b337': 'WjNS+~QRNGWGS4X,yEROI:kXa1N1FgV{ouf$t8bcxbobjce.tQg3'},
#      'Backdrop': {'578ccb194047e306a82109f209182cb4': 'WIH:2Et$5i}bzUyF_1Iok@%3VstUB|IS-XX8OX%N?^nzxGrWRhtm'}},
#     'SeriesStudio': 'Nickelodeon',
#     'ParentThumbItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentThumbImageTag': 'a18096b7adb70b44a86879404e24b337',
#     'Chapters': [],
#     'Trickplay': {},
#     'LocationType': 'FileSystem',
#     'MediaType': 'Video',
#     'LockedFields': [],
#     'LockData': False,
#     'Width': 1536,
#     'Height': 1024},
#    {'Name': '9. epizód',
#     'ServerId': '5044f8c0502743b09777364723ddc2e0',
#     'Id': 'ed0dc8d99452aba9618ff60e50c4220d',
#     'Etag': 'c8fd9498a54245135bb6f695e62794dd',
#     'DateCreated': '2026-03-20T08:09:53.4329053Z',
#     'CanDelete': True,
#     'CanDownload': True,
#     'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#     'SortName': '008 - 0009 - 9. epizód',
#     'PremiereDate': '2013-10-30T00:00:00.0000000Z',
#     'ExternalUrls': [{'Name': 'TMDB',
#       'Url': 'https://www.themoviedb.org/tv/79/season/8/episode/9'}],
#     'MediaSources': [{'Protocol': 'File',
#       'Id': 'ed0dc8d99452aba9618ff60e50c4220d',
#       'Path': '/placeholders/jellyfin-placeholder.mp4',
#       'Type': 'Default',
#       'Container': 'mp4',
#       'Size': 263455,
#       'Name': 'Dora The Explorer S08E09',
#       'IsRemote': False,
#       'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#       'RunTimeTicks': 144000000,
#       'ReadAtNativeFramerate': False,
#       'IgnoreDts': False,
#       'IgnoreIndex': False,
#       'GenPtsInput': False,
#       'SupportsTranscoding': True,
#       'SupportsDirectStream': True,
#       'SupportsDirectPlay': True,
#       'IsInfiniteStream': False,
#       'UseMostCompatibleTranscodingProfile': False,
#       'RequiresOpening': False,
#       'RequiresClosing': False,
#       'RequiresLooping': False,
#       'SupportsProbing': True,
#       'VideoType': 'VideoFile',
#       'MediaStreams': [{'Codec': 'h264',
#         'CodecTag': 'avc1',
#         'Language': 'und',
#         'ColorSpace': 'bt709',
#         'ColorTransfer': 'bt709',
#         'ColorPrimaries': 'bt709',
#         'TimeBase': '1/24000',
#         'VideoRange': 'SDR',
#         'VideoRangeType': 'SDR',
#         'AudioSpatialFormat': 'None',
#         'DisplayTitle': '1080p H264 SDR',
#         'NalLengthSize': '4',
#         'IsInterlaced': False,
#         'IsAVC': True,
#         'BitRate': 137779,
#         'BitDepth': 8,
#         'RefFrames': 1,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Height': 1024,
#         'Width': 1536,
#         'AverageFrameRate': 23.976025,
#         'RealFrameRate': 23.976025,
#         'ReferenceFrameRate': 23.976025,
#         'Profile': 'High',
#         'Type': 'Video',
#         'AspectRatio': '1.5:1',
#         'Index': 0,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'PixelFormat': 'yuv420p',
#         'Level': 40,
#         'IsAnamorphic': False},
#        {'Codec': 'aac',
#         'CodecTag': 'mp4a',
#         'Language': 'und',
#         'TimeBase': '1/48000',
#         'VideoRange': 'Unknown',
#         'VideoRangeType': 'Unknown',
#         'AudioSpatialFormat': 'None',
#         'LocalizedDefault': 'Default',
#         'LocalizedExternal': 'External',
#         'DisplayTitle': 'AAC - Stereo - Default',
#         'IsInterlaced': False,
#         'IsAVC': False,
#         'ChannelLayout': 'stereo',
#         'BitRate': 2278,
#         'Channels': 2,
#         'SampleRate': 48000,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Profile': 'LC',
#         'Type': 'Audio',
#         'Index': 1,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'Level': 0}],
#       'MediaAttachments': [],
#       'Formats': [],
#       'Bitrate': 146363,
#       'RequiredHttpHeaders': {},
#       'TranscodingSubProtocol': 'http',
#       'HasSegments': False}],
#     'Path': '/series/Dora The Explorer [imdbid-tt0235917]/Season 8/Dora The Explorer S08E09.mkv',
#     'EnableMediaSourceDisplay': True,
#     'ChannelId': None,
#     'Taglines': [],
#     'Genres': [],
#     'RunTimeTicks': 144000000,
#     'ProductionYear': 2013,
#     'IndexNumber': 9,
#     'ParentIndexNumber': 8,
#     'RemoteTrailers': [],
#     'ProviderIds': {'Tvdb': '4699676'},
#     'IsHD': True,
#     'IsFolder': False,
#     'ParentId': '1640c2cb619ca731b80f629d4b447fda',
#     'Type': 'Episode',
#     'People': [{'Name': 'Kathleen Herles',
#       'Id': 'a6487ed0a27471ce7d8ceb47352d05ad',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8fccb6f8036aec52eb6505173767447d',
#       'ImageBlurHashes': {'Primary': {'8fccb6f8036aec52eb6505173767447d': 'dNFXegt70#NG%MWWE2WBtlNH$MjsgObHwIWqx]kCRjoJ'}}},
#      {'Name': 'Marc Weiner',
#       'Id': '201a02f6a42d59bae6025817e908acca',
#       'Role': 'Map / Swiper (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '8ecd13895d0860586929a6549d3f3e98',
#       'ImageBlurHashes': {'Primary': {'8ecd13895d0860586929a6549d3f3e98': 'dVF4_.-o0gIp$zj?RjoJ9uNHxaWXM|WVoybHIpWVxas:'}}},
#      {'Name': 'Caitlin Sanchez',
#       'Id': '63be2715c1ff4d23c2296f83e3cfa78d',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Ashley Flemming',
#       'Id': '5b14b4cfac799d67bea446da50e69f5e',
#       'Role': 'Isa (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Jacob Medrano',
#       'Id': '8f2a6dfc95c52e60cf9d0f3489cb3fb8',
#       'Role': 'Diego (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Alexandria Suarez',
#       'Id': 'a98b972f3d05f3fa21904ad9ab8c61ca',
#       'Role': 'Backpack (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': 'f517961d8a862e075b1e930541a5ef72',
#       'ImageBlurHashes': {'Primary': {'f517961d8a862e075b1e930541a5ef72': 'dLCr+S$j0|V]5kNt%1xtOUxt-oS2JjR*o{R*?GofI:WC'}}},
#      {'Name': 'Jose Zelaya',
#       'Id': 'ef9bc1425ff59d71cd69db672a42b2c9',
#       'Role': 'Tico (voice)',
#       'Type': 'Actor',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Dolly Peter Lopes',
#       'Id': '036f25b6a61fffa050c93d8d023c13a5',
#       'Role': 'Dora (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '4acecb330a908445cec808e9a489cfdd',
#       'ImageBlurHashes': {'Primary': {'4acecb330a908445cec808e9a489cfdd': 'dLHmisrC0#CR0JTxENIAXmIU$Nw{RR$+%1SzFxIp$%%2'}}},
#      {'Name': 'Fatima Ptacek',
#       'Id': 'e5a17093c5c74851fd4c2751a2d0d90a',
#       'Role': 'Dora the Explorer (voice)',
#       'Type': 'Actor',
#       'PrimaryImageTag': '7b8e66676a30db640504e8a7097eb353',
#       'ImageBlurHashes': {'Primary': {'7b8e66676a30db640504e8a7097eb353': 'daFr3J-p0fNI9|S4xaR,bcj[%2xaIpRkofjuWYWBs.s:'}}}],
#     'Studios': [],
#     'GenreItems': [],
#     'ParentLogoItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentBackdropImageTags': ['578ccb194047e306a82109f209182cb4'],
#     'LocalTrailerCount': 0,
#     'SeriesName': 'Dóra, a felfedező',
#     'SeriesId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'SeasonId': '1640c2cb619ca731b80f629d4b447fda',
#     'SpecialFeatureCount': 0,
#     'DisplayPreferencesId': '26dd4a82b00c839c498471cdba80a99c',
#     'Tags': [],
#     'PrimaryImageAspectRatio': 1.7777777777777777,
#     'SeriesPrimaryImageTag': '5abd37fca61ac5014f6f8f050503b49d',
#     'SeasonName': 'Season 8',
#     'MediaStreams': [{'Codec': 'h264',
#       'CodecTag': 'avc1',
#       'Language': 'und',
#       'ColorSpace': 'bt709',
#       'ColorTransfer': 'bt709',
#       'ColorPrimaries': 'bt709',
#       'TimeBase': '1/24000',
#       'VideoRange': 'SDR',
#       'VideoRangeType': 'SDR',
#       'AudioSpatialFormat': 'None',
#       'DisplayTitle': '1080p H264 SDR',
#       'NalLengthSize': '4',
#       'IsInterlaced': False,
#       'IsAVC': True,
#       'BitRate': 137779,
#       'BitDepth': 8,
#       'RefFrames': 1,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Height': 1024,
#       'Width': 1536,
#       'AverageFrameRate': 23.976025,
#       'RealFrameRate': 23.976025,
#       'ReferenceFrameRate': 23.976025,
#       'Profile': 'High',
#       'Type': 'Video',
#       'AspectRatio': '1.5:1',
#       'Index': 0,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'PixelFormat': 'yuv420p',
#       'Level': 40,
#       'IsAnamorphic': False},
#      {'Codec': 'aac',
#       'CodecTag': 'mp4a',
#       'Language': 'und',
#       'TimeBase': '1/48000',
#       'VideoRange': 'Unknown',
#       'VideoRangeType': 'Unknown',
#       'AudioSpatialFormat': 'None',
#       'LocalizedDefault': 'Default',
#       'LocalizedExternal': 'External',
#       'DisplayTitle': 'AAC - Stereo - Default',
#       'IsInterlaced': False,
#       'IsAVC': False,
#       'ChannelLayout': 'stereo',
#       'BitRate': 2278,
#       'Channels': 2,
#       'SampleRate': 48000,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Profile': 'LC',
#       'Type': 'Audio',
#       'Index': 1,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'Level': 0}],
#     'VideoType': 'VideoFile',
#     'ImageTags': {'Primary': '16f8b7238193f9bd00183d68ac3df9d6'},
#     'BackdropImageTags': [],
#     'ParentLogoImageTag': '86210232e0bd21a1894ea46bc9327327',
#     'ImageBlurHashes': {'Primary': {'16f8b7238193f9bd00183d68ac3df9d6': 'W]KoPvn9Y2tRoMt+LgkpV_bvoyWYTJbIn6aLV[nP%KoMk8j=bEj=',
#       '5abd37fca61ac5014f6f8f050503b49d': 'dOK1t5VB5OyD^-9XS%tnCkR+#Rnm*IEdx@xvx]OUXlOs'},
#      'Logo': {'86210232e0bd21a1894ea46bc9327327': 'NLJ8V0of4nxu9FM{~q%M%Mt7WBM{4n?bRj%M%MWB'},
#      'Thumb': {'a18096b7adb70b44a86879404e24b337': 'WjNS+~QRNGWGS4X,yEROI:kXa1N1FgV{ouf$t8bcxbobjce.tQg3'},
#      'Backdrop': {'578ccb194047e306a82109f209182cb4': 'WIH:2Et$5i}bzUyF_1Iok@%3VstUB|IS-XX8OX%N?^nzxGrWRhtm'}},
#     'SeriesStudio': 'Nickelodeon',
#     'ParentThumbItemId': '5c57fa86871fe0c90c45629bdcd453c4',
#     'ParentThumbImageTag': 'a18096b7adb70b44a86879404e24b337',
#     'Chapters': [],
#     'Trickplay': {},
#     'LocationType': 'FileSystem',
#     'MediaType': 'Video',
#     'LockedFields': [],
#     'LockData': False,
#     'Width': 1536,
#     'Height': 1024},
#    {'Name': '10. epizód',
#     'ServerId': '5044f8c0502743b09777364723ddc2e0',
#     'Id': '5de9516e830cefc18a0458248338fd3e',
#     'Etag': '3c2036485d096dba637ef40fbb117ea9',
#     'DateCreated': '2026-03-20T08:09:53.4329053Z',
#     'CanDelete': True,
#     'CanDownload': True,
#     'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#     'SortName': '008 - 0010 - 10. epizód',
#     'PremiereDate': '2013-11-25T00:00:00.0000000Z',
#     'ExternalUrls': [{'Name': 'IMDb',
#       'Url': 'https://www.imdb.com/title/tt3347630'},
#      {'Name': 'TMDB',
#       'Url': 'https://www.themoviedb.org/tv/79/season/8/episode/10'}],
#     'MediaSources': [{'Protocol': 'File',
#       'Id': '5de9516e830cefc18a0458248338fd3e',
#       'Path': '/placeholders/jellyfin-placeholder.mp4',
#       'Type': 'Default',
#       'Container': 'mp4',
#       'Size': 263455,
#       'Name': 'Dora The Explorer S08E10',
# ...
#   'Capabilities': {'PlayableMediaTypes': ['Audio', 'Video'],
#    'SupportedCommands': ['MoveUp',
#     'MoveDown',
#     'MoveLeft',
#     'MoveRight',
#     'PageUp',
#     'PageDown',
#     'PreviousLetter',
#     'NextLetter',
#     'ToggleOsd',
#     'ToggleContextMenu',
#     'Select',
#     'Back',
#     'SendKey',
#     'SendString',
#     'GoHome',
#     'GoToSettings',
#     'VolumeUp',
#     'VolumeDown',
#     'Mute',
#     'Unmute',
#     'ToggleMute',
#     'SetVolume',
#     'SetAudioStreamIndex',
#     'SetSubtitleStreamIndex',
#     'DisplayContent',
#     'GoToSearch',
#     'DisplayMessage',
#     'SetRepeatMode',
#     'SetShuffleQueue',
#     'ChannelUp',
#     'ChannelDown',
#     'PlayMediaSource',
#     'PlayTrailers'],
#    'SupportsMediaControl': True,
#    'SupportsPersistentIdentifier': False},
#   'RemoteEndPoint': '192.168.0.230',
#   'PlayableMediaTypes': ['Audio', 'Video'],
#   'Id': 'c0273a366499843aab873a9b7bf6d674',
#   'UserId': 'e3cc30114c354b68995e36c06793dedc',
#   'UserName': 'szucsiki',
#   'Client': 'Jellyfin iOS',
#   'LastActivityDate': '2026-04-22T07:22:18.646973Z',
#   'LastPlaybackCheckIn': '2026-04-22T07:22:15.6448814Z',
#   'DeviceName': 'iPhone',
#   'NowPlayingItem': {'Name': 'Hiroshima igaz története',
#    'OriginalTitle': 'Hiroshima: The Aftermath',
#    'ServerId': '5044f8c0502743b09777364723ddc2e0',
#    'Id': '8793e335e0d1a2854393785a1ddf93b5',
#    'DateCreated': '2026-03-20T08:09:53.4329053Z',
#    'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#    'PremiereDate': '2015-06-06T00:00:00.0000000Z',
#    'ExternalUrls': [{'Name': 'IMDb',
#      'Url': 'https://www.imdb.com/title/tt4835456'},
#     {'Name': 'TMDB', 'Url': 'https://www.themoviedb.org/movie/358269'}],
#    'Path': '/movies/Hiroshima igaz tortenete 1080i [imdbid-tt4835456]/Hiroshima igaz tortenete.mkv',
#    'EnableMediaSourceDisplay': True,
#    'ChannelId': None,
#    'Overview': 'Hét évtizede éve történt a hiroshimai atomtámadás. A japán nagyvárosra ledobott atombomba új korszakot nyitott a történelemben: a szörnyű pusztításon túl végleg lezárta a sok millió ember értelmetlen halálát követelő második világháborút. Az ezt követő időszakot nevezhetjük atomkorszaknak vagy hidegháborúnak is: a kölcsönös elrettentés lett az alapja évtizedeken keresztül az igencsak kényes erőegyensúlynak a kétpólusú világban.',
#    'Taglines': [],
#    'Genres': ['Dokumentum', 'Történelmi', 'Háborús'],
#    'CommunityRating': 7.971,
#    'RunTimeTicks': 144000000,
#    'ProductionYear': 2015,
#    'ProviderIds': {'Imdb': 'tt4835456', 'Tmdb': '358269'},
#    'IsHD': True,
#    'IsFolder': False,
#    'ParentId': '5b0d238e2f6d5609b709d7b76300e217',
#    'Type': 'Movie',
#    'Studios': [{'Name': 'Brook Lapping Productions',
#      'Id': '7c956004428459cee7801389032f482d'}],
#    'GenreItems': [{'Name': 'Dokumentum',
#      'Id': 'ba5e71dd1312d5ff7bdd377eda02990a'},
#     {'Name': 'Történelmi', 'Id': '5253d158a034ac204928ae0a88b80880'},
#     {'Name': 'Háborús', 'Id': '94f96c6d549b50dba54247ae6f389c8e'}],
#    'LocalTrailerCount': 0,
#    'SpecialFeatureCount': 0,
#    'PrimaryImageAspectRatio': 0.666,
#    'MediaStreams': [{'Codec': 'h264',
#      'CodecTag': 'avc1',
#      'Language': 'und',
#      'ColorSpace': 'bt709',
#      'ColorTransfer': 'bt709',
#      'ColorPrimaries': 'bt709',
#      'TimeBase': '1/24000',
#      'VideoRange': 'SDR',
#      'VideoRangeType': 'SDR',
#      'AudioSpatialFormat': 'None',
#      'DisplayTitle': '1080p H264 SDR',
#      'NalLengthSize': '4',
#      'IsInterlaced': False,
#      'IsAVC': True,
#      'BitRate': 137779,
#      'BitDepth': 8,
#      'RefFrames': 1,
#      'IsDefault': True,
#      'IsForced': False,
#      'IsHearingImpaired': False,
#      'Height': 1024,
#      'Width': 1536,
#      'AverageFrameRate': 23.976025,
#      'RealFrameRate': 23.976025,
#      'ReferenceFrameRate': 23.976025,
#      'Profile': 'High',
#      'Type': 'Video',
#      'AspectRatio': '1.5:1',
#      'Index': 0,
#      'IsExternal': False,
#      'IsTextSubtitleStream': False,
#      'SupportsExternalStream': False,
#      'PixelFormat': 'yuv420p',
#      'Level': 40,
#      'IsAnamorphic': False},
#     {'Codec': 'aac',
#      'CodecTag': 'mp4a',
#      'Language': 'und',
#      'TimeBase': '1/48000',
#      'VideoRange': 'Unknown',
#      'VideoRangeType': 'Unknown',
#      'AudioSpatialFormat': 'None',
#      'LocalizedDefault': 'Default',
#      'LocalizedExternal': 'External',
#      'DisplayTitle': 'AAC - Stereo - Default',
#      'IsInterlaced': False,
#      'IsAVC': False,
#      'ChannelLayout': 'stereo',
#      'BitRate': 2278,
#      'Channels': 2,
#      'SampleRate': 48000,
#      'IsDefault': True,
#      'IsForced': False,
#      'IsHearingImpaired': False,
#      'Profile': 'LC',
#      'Type': 'Audio',
#      'Index': 1,
#      'IsExternal': False,
#      'IsTextSubtitleStream': False,
#      'SupportsExternalStream': False,
#      'Level': 0}],
#    'VideoType': 'VideoFile',
#    'ImageTags': {'Primary': 'f865a892f982f0e14867e8ed9fbe0a56'},
#    'BackdropImageTags': [],
#    'ImageBlurHashes': {'Primary': {'f865a892f982f0e14867e8ed9fbe0a56': 'dUIY5[xu%M-;~qfPofxu_3j[WU%Mt7WBt8ofRjRjRjWB'}},
#    'Chapters': [],
#    'Trickplay': {},
#    'LocationType': 'FileSystem',
#    'MediaType': 'Video',
#    'Width': 1536,
#    'Height': 1024},
#   'DeviceId': '61c11407-f99a-4455-bba5-9f5175afcfc9',
#   'ApplicationVersion': '1.7.0',
#   'IsActive': True,
#   'SupportsMediaControl': True,
#   'SupportsRemoteControl': True,
#   'NowPlayingQueue': [{'Id': '8793e335e0d1a2854393785a1ddf93b5',
#     'PlaylistItemId': 'playlistItem0'}],
#   'NowPlayingQueueFullItems': [{'Name': 'Hiroshima igaz története',
#     'OriginalTitle': 'Hiroshima: The Aftermath',
#     'ServerId': '5044f8c0502743b09777364723ddc2e0',
#     'Id': '8793e335e0d1a2854393785a1ddf93b5',
#     'Etag': '4a57f7681578ae56670c2b24518379c4',
#     'DateCreated': '2026-03-20T08:09:53.4329053Z',
#     'CanDelete': True,
#     'CanDownload': True,
#     'Container': 'mov,mp4,m4a,3gp,3g2,mj2',
#     'SortName': 'hiroshima igaz tortenete',
#     'PremiereDate': '2015-06-06T00:00:00.0000000Z',
#     'ExternalUrls': [{'Name': 'IMDb',
#       'Url': 'https://www.imdb.com/title/tt4835456'},
#      {'Name': 'TMDB', 'Url': 'https://www.themoviedb.org/movie/358269'}],
#     'MediaSources': [{'Protocol': 'File',
#       'Id': '8793e335e0d1a2854393785a1ddf93b5',
#       'Path': '/placeholders/jellyfin-placeholder.mp4',
#       'Type': 'Default',
#       'Container': 'mp4',
#       'Size': 263455,
#       'Name': 'Hiroshima igaz tortenete',
#       'IsRemote': False,
#       'ETag': '2eef7b1e4a384109e1aa9a499b4393f2',
#       'RunTimeTicks': 144000000,
#       'ReadAtNativeFramerate': False,
#       'IgnoreDts': False,
#       'IgnoreIndex': False,
#       'GenPtsInput': False,
#       'SupportsTranscoding': True,
#       'SupportsDirectStream': True,
#       'SupportsDirectPlay': True,
#       'IsInfiniteStream': False,
#       'UseMostCompatibleTranscodingProfile': False,
#       'RequiresOpening': False,
#       'RequiresClosing': False,
#       'RequiresLooping': False,
#       'SupportsProbing': True,
#       'VideoType': 'VideoFile',
#       'MediaStreams': [{'Codec': 'h264',
#         'CodecTag': 'avc1',
#         'Language': 'und',
#         'ColorSpace': 'bt709',
#         'ColorTransfer': 'bt709',
#         'ColorPrimaries': 'bt709',
#         'TimeBase': '1/24000',
#         'VideoRange': 'SDR',
#         'VideoRangeType': 'SDR',
#         'AudioSpatialFormat': 'None',
#         'DisplayTitle': '1080p H264 SDR',
#         'NalLengthSize': '4',
#         'IsInterlaced': False,
#         'IsAVC': True,
#         'BitRate': 137779,
#         'BitDepth': 8,
#         'RefFrames': 1,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Height': 1024,
#         'Width': 1536,
#         'AverageFrameRate': 23.976025,
#         'RealFrameRate': 23.976025,
#         'ReferenceFrameRate': 23.976025,
#         'Profile': 'High',
#         'Type': 'Video',
#         'AspectRatio': '1.5:1',
#         'Index': 0,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'PixelFormat': 'yuv420p',
#         'Level': 40,
#         'IsAnamorphic': False},
#        {'Codec': 'aac',
#         'CodecTag': 'mp4a',
#         'Language': 'und',
#         'TimeBase': '1/48000',
#         'VideoRange': 'Unknown',
#         'VideoRangeType': 'Unknown',
#         'AudioSpatialFormat': 'None',
#         'LocalizedDefault': 'Default',
#         'LocalizedExternal': 'External',
#         'DisplayTitle': 'AAC - Stereo - Default',
#         'IsInterlaced': False,
#         'IsAVC': False,
#         'ChannelLayout': 'stereo',
#         'BitRate': 2278,
#         'Channels': 2,
#         'SampleRate': 48000,
#         'IsDefault': True,
#         'IsForced': False,
#         'IsHearingImpaired': False,
#         'Profile': 'LC',
#         'Type': 'Audio',
#         'Index': 1,
#         'IsExternal': False,
#         'IsTextSubtitleStream': False,
#         'SupportsExternalStream': False,
#         'Level': 0}],
#       'MediaAttachments': [],
#       'Formats': [],
#       'Bitrate': 146363,
#       'RequiredHttpHeaders': {},
#       'TranscodingSubProtocol': 'http',
#       'HasSegments': False}],
#     'ProductionLocations': ['United Kingdom'],
#     'Path': '/movies/Hiroshima igaz tortenete 1080i [imdbid-tt4835456]/Hiroshima igaz tortenete.mkv',
#     'EnableMediaSourceDisplay': True,
#     'ChannelId': None,
#     'Overview': 'Hét évtizede éve történt a hiroshimai atomtámadás. A japán nagyvárosra ledobott atombomba új korszakot nyitott a történelemben: a szörnyű pusztításon túl végleg lezárta a sok millió ember értelmetlen halálát követelő második világháborút. Az ezt követő időszakot nevezhetjük atomkorszaknak vagy hidegháborúnak is: a kölcsönös elrettentés lett az alapja évtizedeken keresztül az igencsak kényes erőegyensúlynak a kétpólusú világban.',
#     'Taglines': [],
#     'Genres': ['Dokumentum', 'Történelmi', 'Háborús'],
#     'CommunityRating': 7.971,
#     'RunTimeTicks': 144000000,
#     'ProductionYear': 2015,
#     'RemoteTrailers': [],
#     'ProviderIds': {'Imdb': 'tt4835456', 'Tmdb': '358269'},
#     'IsHD': True,
#     'IsFolder': False,
#     'ParentId': '5b0d238e2f6d5609b709d7b76300e217',
#     'Type': 'Movie',
#     'People': [{'Name': 'John Sessions',
#       'Id': '5f6dd7f2f08b6a30e56b3389a9ca966e',
#       'Role': 'Narrator',
#       'Type': 'Actor',
#       'PrimaryImageTag': '9045b6bf8aed3c864201bf72a2c5fefe',
#       'ImageBlurHashes': {'Primary': {'9045b6bf8aed3c864201bf72a2c5fefe': 'dNAu{kR*0zxZ-AbHI;jYADoJ$%S4EMoL$%WCNGj[t6WB'}}},
#      {'Name': 'Yoko Imai',
#       'Id': '1cc777f6ca082d49e70ede2baefc6f41',
#       'Role': 'Producer',
#       'Type': 'Producer',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Motonari Takaura',
#       'Id': 'a392c3709dcd5605c75d51228aad019f',
#       'Role': 'Producer',
#       'Type': 'Producer',
#       'ImageBlurHashes': {'Primary': {}}},
#      {'Name': 'Takaaki Takai',
#       'Id': '6f287f35272c1175e725cba035bbb8b0',
#       'Role': 'Producer',
#       'Type': 'Producer',
#       'ImageBlurHashes': {'Primary': {}}}],
#     'Studios': [{'Name': 'Brook Lapping Productions',
#       'Id': '7c956004428459cee7801389032f482d'}],
#     'GenreItems': [{'Name': 'Dokumentum',
#       'Id': 'ba5e71dd1312d5ff7bdd377eda02990a'},
#      {'Name': 'Történelmi', 'Id': '5253d158a034ac204928ae0a88b80880'},
#      {'Name': 'Háborús', 'Id': '94f96c6d549b50dba54247ae6f389c8e'}],
#     'LocalTrailerCount': 0,
#     'SpecialFeatureCount': 0,
#     'DisplayPreferencesId': 'dbf7709c41faaa746463d67978eb863d',
#     'Tags': ['war crimes',
#      'atomic bomb',
#      'world war ii',
#      'interview',
#      'hiroshima, japan',
#      'little boy',
#      'archive footage',
#      'old footage',
#      'testimony',
#      'hiroshima and nagasaki bombings',
#      'hiroshima bombing'],
#     'PrimaryImageAspectRatio': 0.666,
#     'MediaStreams': [{'Codec': 'h264',
#       'CodecTag': 'avc1',
#       'Language': 'und',
#       'ColorSpace': 'bt709',
#       'ColorTransfer': 'bt709',
#       'ColorPrimaries': 'bt709',
#       'TimeBase': '1/24000',
#       'VideoRange': 'SDR',
#       'VideoRangeType': 'SDR',
#       'AudioSpatialFormat': 'None',
#       'DisplayTitle': '1080p H264 SDR',
#       'NalLengthSize': '4',
#       'IsInterlaced': False,
#       'IsAVC': True,
#       'BitRate': 137779,
#       'BitDepth': 8,
#       'RefFrames': 1,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Height': 1024,
#       'Width': 1536,
#       'AverageFrameRate': 23.976025,
#       'RealFrameRate': 23.976025,
#       'ReferenceFrameRate': 23.976025,
#       'Profile': 'High',
#       'Type': 'Video',
#       'AspectRatio': '1.5:1',
#       'Index': 0,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'PixelFormat': 'yuv420p',
#       'Level': 40,
#       'IsAnamorphic': False},
#      {'Codec': 'aac',
#       'CodecTag': 'mp4a',
#       'Language': 'und',
#       'TimeBase': '1/48000',
#       'VideoRange': 'Unknown',
#       'VideoRangeType': 'Unknown',
#       'AudioSpatialFormat': 'None',
#       'LocalizedDefault': 'Default',
#       'LocalizedExternal': 'External',
#       'DisplayTitle': 'AAC - Stereo - Default',
#       'IsInterlaced': False,
#       'IsAVC': False,
#       'ChannelLayout': 'stereo',
#       'BitRate': 2278,
#       'Channels': 2,
#       'SampleRate': 48000,
#       'IsDefault': True,
#       'IsForced': False,
#       'IsHearingImpaired': False,
#       'Profile': 'LC',
#       'Type': 'Audio',
#       'Index': 1,
#       'IsExternal': False,
#       'IsTextSubtitleStream': False,
#       'SupportsExternalStream': False,
#       'Level': 0}],
#     'VideoType': 'VideoFile',
#     'ImageTags': {'Primary': 'f865a892f982f0e14867e8ed9fbe0a56'},
#     'BackdropImageTags': [],
#     'ImageBlurHashes': {'Primary': {'f865a892f982f0e14867e8ed9fbe0a56': 'dUIY5[xu%M-;~qfPofxu_3j[WU%Mt7WBt8ofRjRjRjWB'}},
#     'Chapters': [],
#     'Trickplay': {},
#     'LocationType': 'FileSystem',
#     'MediaType': 'Video',
#     'LockedFields': [],
#     'LockData': False,
#     'Width': 1536,
#     'Height': 1024}],
#   'HasCustomDeviceName': False,
#   'PlaylistItemId': 'playlistItem0',
#   'ServerId': '5044f8c0502743b09777364723ddc2e0',
#   'SupportedCommands': ['MoveUp',
#    'MoveDown',
#    'MoveLeft',
#    'MoveRight',
#    'PageUp',
#    'PageDown',
#    'PreviousLetter',
#    'NextLetter',
#    'ToggleOsd',
#    'ToggleContextMenu',
#    'Select',
#    'Back',
#    'SendKey',
#    'SendString',
#    'GoHome',
#    'GoToSettings',
#    'VolumeUp',
#    'VolumeDown',
#    'Mute',
#    'Unmute',
#    'ToggleMute',
#    'SetVolume',
#    'SetAudioStreamIndex',
#    'SetSubtitleStreamIndex',
#    'DisplayContent',
#    'GoToSearch',
#    'DisplayMessage',
#    'SetRepeatMode',
#    'SetShuffleQueue',
#    'ChannelUp',
#    'ChannelDown',
#    'PlayMediaSource',
#    'PlayTrailers']},
#  {'PlayState': {'CanSeek': False,
#    'IsPaused': False,
#    'IsMuted': False,
#    'RepeatMode': 'RepeatNone',
#    'PlaybackOrder': 'Default'},
#   'AdditionalUsers': [],
#   'Capabilities': {'PlayableMediaTypes': ['Video', 'Audio'],
#    'SupportedCommands': ['DisplayContent',
#     'SetSubtitleStreamIndex',
#     'SetAudioStreamIndex',
#     'DisplayMessage',
#     'SendString',
#     'VolumeUp',
#     'VolumeDown',
#     'SetVolume',
#     'Mute',
#     'Unmute',
#     'ToggleMute'],
#    'SupportsMediaControl': True,
#    'SupportsPersistentIdentifier': True},
#   'RemoteEndPoint': '192.168.0.167',
#   'PlayableMediaTypes': ['Video', 'Audio'],
#   'Id': '15d4618dc3e79c4fe1590163233d141e',
#   'UserId': 'e3cc30114c354b68995e36c06793dedc',
#   'UserName': 'szucsiki',
#   'Client': 'Jellyfin Android TV',
#   'LastActivityDate': '2026-04-22T06:46:03.5287439Z',
#   'LastPlaybackCheckIn': '2026-04-22T06:45:56.9276248Z',
#   'LastPausedDate': '2026-04-21T21:21:52.6188558Z',
#   'DeviceName': 'Xiaomi médiabox',
#   'DeviceId': '67c2639054cf1858ee945043c1bf57e4828f9ae0',
#   'ApplicationVersion': '0.19.7',
#   'IsActive': True,
#   'SupportsMediaControl': False,
#   'SupportsRemoteControl': False,
#   'NowPlayingQueue': [],
#   'NowPlayingQueueFullItems': [],
#   'HasCustomDeviceName': False,
#   'ServerId': '5044f8c0502743b09777364723ddc2e0',
#   'SupportedCommands': ['DisplayContent',
#    'SetSubtitleStreamIndex',
#    'SetAudioStreamIndex',
#    'DisplayMessage',
#    'SendString',
#    'VolumeUp',
#    'VolumeDown',
#    'SetVolume',
#    'Mute',
#    'Unmute',
#    'ToggleMute']}]
